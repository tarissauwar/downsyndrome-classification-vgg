# %% [markdown]
# # New Section

# %%
import os
import random
from shutil import copy
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from sklearn.model_selection import KFold

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Path ke dataset di Google Drive
DATASET_DIR = '/content/drive/MyDrive/DATASET/ASIA'
categories = ['Down Syndrome', 'Healthy']

# Inisialisasi total gambar
total_images = 0

print("Renaming Results:")
print("=================")

for category in categories:
    category_dir = os.path.join(DATASET_DIR, category)
    if os.path.isdir(category_dir):
        count = 0  # Counter untuk setiap kategori
        for idx, filename in enumerate(os.listdir(category_dir), start=1):
            old_path = os.path.join(category_dir, filename)
            if os.path.isfile(old_path):
                # Buat nama baru
                new_filename = f"{category.replace(' ', '_')}_{idx:03}.jpg"  # Ganti spasi dengan underscore
                new_path = os.path.join(category_dir, new_filename)
                os.rename(old_path, new_path)
                count += 1
                print(f"{filename} -> {new_filename}")
        print(f"\nJumlah gambar di kategori '{category}': {count}")
        total_images += count

print("\n=================")
print(f"Total gambar di dataset: {total_images}")
# Out:
# Renaming Results:
# =================
# down_1010_jpg.rf.323af843c2078ee6e56bed36f8ba08a8.jpg -> Down_Syndrome_001.jpg
# down_1007_jpg.rf.40bb1cba224172669a417fa349b95ac8.jpg -> Down_Syndrome_002.jpg
# down_1005_jpg.rf.c17f750685ba5cfea73dc058a367edad.jpg -> Down_Syndrome_003.jpg
# down_1008_jpg.rf.315e6e56a1f05562ee70703880c39b71.jpg -> Down_Syndrome_004.jpg
# down_1009_jpg.rf.a9fdf45ab35209df6e85b17af19bb4da.jpg -> Down_Syndrome_005.jpg
# down_1004_jpg.rf.49b05473862427c71a433d70574561e0.jpg -> Down_Syndrome_006.jpg
# down_1021_jpg.rf.ae69ae115e093b19efa0fc3f946f5966.jpg -> Down_Syndrome_007.jpg
# down_1017_jpg.rf.edce7e2746cf56b66c1e46b8ad267023.jpg -> Down_Syndrome_008.jpg
# down_101_jpg.rf.24055da8950fd9910f5c68927d1746ed.jpg -> Down_Syndrome_009.jpg
# down_1018_jpg.rf.dc8da05bb734efa9f7d0e34c91f1ef6f.jpg -> Down_Syndrome_010.jpg
# down_1013_jpg.rf.122a12d29b934582b4b44cb56ae9fd8d.jpg -> Down_Syndrome_011.jpg
# down_1026_jpg.rf.afaa152a18054bf7008a70b4bcda7c24.jpg -> Down_Syndrome_012.jpg
# down_1012_jpg.rf.32d0537b07941c9076657eb085bd1900.jpg -> Down_Syndrome_013.jpg
# down_1028_jpg.rf.3c36957bf0c6609b71d84629ed7f8547.jpg -> Down_Syndrome_014.jpg
# down_1033_jpg.rf.740631c82688ab11613daaa5c80080b4.jpg -> Down_Syndrome_015.jpg
# down_1037_jpg.rf.2ef850b6926ecee234de3fd1e27c748e.jpg -> Down_Syndrome_016.jpg
# down_103_jpg.rf.bde85b160ca071d00b1e806b02337c54.jpg -> Down_Syndrome_017.jpg
# down_102_jpg.rf.a67a70fde7103a566207653241d6e0a4.jpg -> Down_Syndrome_018.jpg
# down_1035_jpg.rf.fb88ddd7fd31aa8182e572493df09f3d.jpg -> Down_Syndrome_019.jpg
# down_1030_jpg.rf.2c2556fc53b2f2bcbd220cbc27500582.jpg -> Down_Syndrome_020.jpg
# down_1053_jpg.rf.dbb93f7ccb9a141342b0d753d898a1f9.jpg -> Down_Syndrome_021.jpg
# down_1042_jpg.rf.b0fe8d33278fa657aebeba3da3215684.jpg -> Down_Syndrome_022.jpg
# down_1056_jpg.rf.f9893f16e263475a530c62a500c8d2ef.jpg -> Down_Syndrome_023.jpg
# down_1063_jpg.rf.1c4f8fdb3c1c98cc2ef4a13d3c3808cf.jpg -> Down_Syndrome_024.jpg
# down_104_jpg.rf.cf6213ea414f7dfcde44b1acc91d69af.jpg -> Down_Syndrome_025.jpg
# down_1044_jpg.rf.e9a2cb03a91325c148e860f617a08a54.jpg -> Down_Syndrome_026.jpg
# down_1047_jpg.rf.2ccecaa94117d64a977b7edfa565bfb5.jpg -> Down_Syndrome_027.jpg
# down_1071_jpg.rf.2e0103495df92f33db96087262f4fa01.jpg -> Down_Syndrome_028.jpg
# down_1077_jpg.rf.32e12fadad0c346473d81d431bfb7c11.jpg -> Down_Syndrome_029.jpg
# down_1070_jpg.rf.4b9d69c59025f105e33810842e9c9304.jpg -> Down_Syndrome_030.jpg
# down_1081_jpg.rf.df3442ce14b8a86a955336687aa69adf.jpg -> Down_Syndrome_031.jpg
# down_1085_jpg.rf.891fe6aef8926e11135c80f45eb5025e.jpg -> Down_Syndrome_032.jpg
# down_1079_jpg.rf.26d193794361f974eb1aecf69d66750e.jpg -> Down_Syndrome_033.jpg
# down_1082_jpg.rf.e562fa38adc5389979f37c6cce919be9.jpg -> Down_Syndrome_034.jpg
# down_108_jpg.rf.736e876553bc11adc45c9d9cae2a7f72.jpg -> Down_Syndrome_035.jpg
# down_1103_jpg.rf.79ef3ed718408d1e77a157635d3e7ae0.jpg -> Down_Syndrome_036.jpg
# down_1102_jpg.rf.1488c821def7a58e23d6e2e8801383fd.jpg -> Down_Syndrome_037.jpg
# down_1104_jpg.rf.d78c5126c775dd3288c7b5a5611bac72.jpg -> Down_Syndrome_038.jpg
# down_1091_jpg.rf.c5b85e94947393650fb603762fdf5a8d.jpg -> Down_Syndrome_039.jpg
# down_1090_jpg.rf.7e510c01acedeadc3c1b621971c7c6a5.jpg -> Down_Syndrome_040.jpg
# down_1092_jpg.rf.64e64ef4a589c61f90237b20c6b13b5c.jpg -> Down_Syndrome_041.jpg
# down_1094_jpg.rf.4225eb0aa87151baae88c37ba8a0a68d.jpg -> Down_Syndrome_042.jpg
# down_1095_jpg.rf.130d21e01902f861657453b9f17a9379.jpg -> Down_Syndrome_043.jpg
# down_1115_jpg.rf.b746962b4268959a6df427bb339e29b6.jpg -> Down_Syndrome_044.jpg
# down_110_jpg.rf.75346e4bc979a99f762febdc23a5f726.jpg -> Down_Syndrome_045.jpg
# down_1116_jpg.rf.343e1001f50ec590ca4334bc0c6acf07.jpg -> Down_Syndrome_046.jpg
# down_1108_jpg.rf.e9822958f77b126f9737826d5853955e.jpg -> Down_Syndrome_047.jpg
# down_1112_jpg.rf.7e2b08ca943a08d40f7c5ea3777935a0.jpg -> Down_Syndrome_048.jpg
# down_1109_jpg.rf.181aef9216997a6165c7b4fa8d56693b.jpg -> Down_Syndrome_049.jpg
# down_1111_jpg.rf.186f7251a9a3419f3d0e0576cf006699.jpg -> Down_Syndrome_050.jpg
# down_1110_jpg.rf.ddd2851a9024ca32b11fff69bdc14b3d.jpg -> Down_Syndrome_051.jpg
# down_1120_jpg.rf.239ccea2a216317b7c088ed93d42958b.jpg -> Down_Syndrome_052.jpg
# down_1121_jpg.rf.cb3434931a2dd9b619165f461021ba95.jpg -> Down_Syndrome_053.jpg
# down_1138_jpg.rf.58334efed79ca59ebd9352771a2c039c.jpg -> Down_Syndrome_054.jpg
# down_1128_jpg.rf.b2ce02407f04586b997c7d7533c0c73d.jpg -> Down_Syndrome_055.jpg
# down_1123_jpg.rf.7bd0126b4f8ab8b29ab154e20203374a.jpg -> Down_Syndrome_056.jpg
# down_1139_jpg.rf.7b198ea4c37f71c81c27cd72f7bf7c26.jpg -> Down_Syndrome_057.jpg
# down_1125_jpg.rf.0f0c66fca02d5e00c7eaaca561d0e021.jpg -> Down_Syndrome_058.jpg
# down_1137_jpg.rf.fca8522fbc044f6f14e7092d081fed6d.jpg -> Down_Syndrome_059.jpg
# down_1140_jpg.rf.2b2b7c5ab71bfd235f8181ff3c98dd2b.jpg -> Down_Syndrome_060.jpg
# down_1136_jpg.rf.d055597c0b802465e39c8796c4fe8d1e.jpg -> Down_Syndrome_061.jpg
# down_1141_jpg.rf.ed45bee7ace2f3e2579dfc450199efaa.jpg -> Down_Syndrome_062.jpg
# down_1164_jpg.rf.fabe27bc7fc155960b1366aa0dcc1988.jpg -> Down_Syndrome_063.jpg
# down_1158_jpg.rf.c6838723d028275cc79204d7f00661a4.jpg -> Down_Syndrome_064.jpg
# down_1165_jpg.rf.9118e91f27cff0e04dadb25b51b5aa1e.jpg -> Down_Syndrome_065.jpg
# down_1163_jpg.rf.ed008ee8e2a8f43fd8c5a272a35fd0c1.jpg -> Down_Syndrome_066.jpg
# down_1148_jpg.rf.a089d0f506eb4cb528aaa98ee13e2949.jpg -> Down_Syndrome_067.jpg
# down_1157_jpg.rf.e33f74015c08753e6e1db8511a8df316.jpg -> Down_Syndrome_068.jpg
# down_1166_jpg.rf.bde7a56d9adbb16cbb49920cf3e476ef.jpg -> Down_Syndrome_069.jpg
# down_1142_jpg.rf.1b77e4303e008e9b1989415856355b82.jpg -> Down_Syndrome_070.jpg
# down_1174_jpg.rf.01a5b1f78eb70cfc7b44f7d49cff9f43.jpg -> Down_Syndrome_071.jpg
# down_1168_jpg.rf.fa39e22a70b4deac7c6677fbd2e39f17.jpg -> Down_Syndrome_072.jpg
# down_1176_jpg.rf.b9b9c7abc02489b7b32d7802104e0656.jpg -> Down_Syndrome_073.jpg
# down_1178_jpg.rf.3813589c60f98bc97d83d192adc8a68e.jpg -> Down_Syndrome_074.jpg
# down_1175_jpg.rf.d9591ebbcfb9d590a3dbc1764dd0de07.jpg -> Down_Syndrome_075.jpg
# down_1177_jpg.rf.c25fb38e5152f94510adfde221d4bd4a.jpg -> Down_Syndrome_076.jpg
# down_1179_jpg.rf.fa59da8fddf8cfcc99d5363e58dd797f.jpg -> Down_Syndrome_077.jpg
# down_1167_jpg.rf.7749766e1824fb486e0f6c297781ee16.jpg -> Down_Syndrome_078.jpg
# down_117_jpg.rf.32fefeab31a093e68bd7ac93a8bfbc92.jpg -> Down_Syndrome_079.jpg
# down_1205_jpg.rf.37b9dc39dd1ff079791f9a4ffd0eb4f6.jpg -> Down_Syndrome_080.jpg
# down_121_jpg.rf.d40667052d9cc583502e592bb48b50f5.jpg -> Down_Syndrome_081.jpg
# down_1215_jpg.rf.52eeee925ba0b5dfd9f1910daf9ee593.jpg -> Down_Syndrome_082.jpg
# down_1187_jpg.rf.c890a2b54a2339275a145efb7a0e3b20.jpg -> Down_Syndrome_083.jpg
# down_1219_jpg.rf.42ec73bb8dd465a20d864903667d8e1b.jpg -> Down_Syndrome_084.jpg
# down_1188_jpg.rf.2ffcd7d8b1a9a7b41319edb143e9324f.jpg -> Down_Syndrome_085.jpg
# down_1216_jpg.rf.89557a60bf16e022b344168b5d1dc375.jpg -> Down_Syndrome_086.jpg
# down_1189_jpg.rf.9b4b6fc0ee575ff8919bfc0a42c93962.jpg -> Down_Syndrome_087.jpg
# down_1181_jpg.rf.7a77c276fec2d78cdf8764188b4f7df4.jpg -> Down_Syndrome_088.jpg
# down_11_jpg.rf.2a66409f92fb4c6a532b95cb0939b150.jpg -> Down_Syndrome_089.jpg
# down_1220_jpg.rf.d5bb03f4683e79edc72bc0a63064a429.jpg -> Down_Syndrome_090.jpg
# down_1233_jpg.rf.1badcf9d69f538a933cd7e8079cf0013.jpg -> Down_Syndrome_091.jpg
# down_123_jpg.rf.e7e077de4f8e48f901cccafe63281c4d.jpg -> Down_Syndrome_092.jpg
# down_1239_jpg.rf.229e50cc5701548b058c53d3c24349ea.jpg -> Down_Syndrome_093.jpg
# down_1237_jpg.rf.5f10daba9379a6d7ba4038d4a299409f.jpg -> Down_Syndrome_094.jpg
# down_1232_jpg.rf.b03209adb3cedf40a143cc1964f824da.jpg -> Down_Syndrome_095.jpg
# down_122_jpg.rf.dc3af36b324382df7e9d4be11711b227.jpg -> Down_Syndrome_096.jpg
# down_1238_jpg.rf.33c65e6c48dc679901b008a2bb1c8ade.jpg -> Down_Syndrome_097.jpg
# down_1221_jpg.rf.65cddd294ddfae875c60935465e57a30.jpg -> Down_Syndrome_098.jpg
# down_1231_jpg.rf.1fcb1ef6b92bd7cf1ea392d4386f45cd.jpg -> Down_Syndrome_099.jpg
# down_1257_jpg.rf.4d8524932c7493f7031eb43e01332069.jpg -> Down_Syndrome_100.jpg
# down_1245_jpg.rf.b6bd378e74b8fe645910560ce18c08b8.jpg -> Down_Syndrome_101.jpg
# down_124_jpg.rf.a0573c9c0b7e95500173dbadf362f82c.jpg -> Down_Syndrome_102.jpg
# down_1255_jpg.rf.e1226662bb3402c786ab5882655d3568.jpg -> Down_Syndrome_103.jpg
# down_1256_jpg.rf.4347f9a5237eb5aec86583c31e62e500.jpg -> Down_Syndrome_104.jpg
# down_1261_jpg.rf.73efdccc2904e7f60871a8d0b4c0a087.jpg -> Down_Syndrome_105.jpg
# down_1260_jpg.rf.2a2895493151dce4b500b27852495052.jpg -> Down_Syndrome_106.jpg
# down_1262_jpg.rf.dad2ed8db0c2353cdb7cf4a23c931865.jpg -> Down_Syndrome_107.jpg
# down_1271_jpg.rf.bb15a2c3f7ae01e68bf2a2a484d88121.jpg -> Down_Syndrome_108.jpg
# down_1276_jpg.rf.03cee777c8ca42c4904fb89ae1e87c12.jpg -> Down_Syndrome_109.jpg
# down_1278_jpg.rf.010d04c1a36708d5b7e4d7ba299eb804.jpg -> Down_Syndrome_110.jpg
# down_1289_jpg.rf.54275cf651daf3af64672db7fbf3fc33.jpg -> Down_Syndrome_111.jpg
# down_1283_jpg.rf.b734e3519468cd01f0802783f39be647.jpg -> Down_Syndrome_112.jpg
# down_1282_jpg.rf.e1709f36385884750309757abf411326.jpg -> Down_Syndrome_113.jpg
# down_1281_jpg.rf.975129cc52ea30e20d589456003a6694.jpg -> Down_Syndrome_114.jpg
# down_1301_jpg.rf.3cac05e2ff37bf0075e99124b301791f.jpg -> Down_Syndrome_115.jpg
# down_1298_jpg.rf.844025229f2b5e6fff5f85350899af1d.jpg -> Down_Syndrome_116.jpg
# down_128_jpg.rf.8c6f36932b25da257d4ac291be668419.jpg -> Down_Syndrome_117.jpg
# down_1288_jpg.rf.48153613d0c8c8bc6bf27e1d2491b6ed.jpg -> Down_Syndrome_118.jpg
# down_127_jpg.rf.49390db2c22b260649c1d299404a20d7.jpg -> Down_Syndrome_119.jpg
# down_1320_jpg.rf.098a342b7f3abb1808b8c3f562d8c524.jpg -> Down_Syndrome_120.jpg
# down_1323_jpg.rf.64ed545f1779680b69be53c55b5560a6.jpg -> Down_Syndrome_121.jpg
# down_1302_jpg.rf.eb3416e65be2c72da8619e36d6bf76d2.jpg -> Down_Syndrome_122.jpg
# down_1306_jpg.rf.8bb04d4ee0f37c1cb1b8718dff24fac2.jpg -> Down_Syndrome_123.jpg
# down_1324_jpg.rf.cf39b6a859345d6abfcfc8be32da3da6.jpg -> Down_Syndrome_124.jpg
# down_130_jpg.rf.19babb281dd6704e4b326ddf9bcedcc4.jpg -> Down_Syndrome_125.jpg
# down_1321_jpg.rf.7b7c638eba03f54a53ff9c4d9d06a4e6.jpg -> Down_Syndrome_126.jpg
# down_1305_jpg.rf.ce7e8ac1b603e1f752c949e05e19df3b.jpg -> Down_Syndrome_127.jpg
# down_1307_jpg.rf.d7f70f40da8bebc90c867bf98d6fc63f.jpg -> Down_Syndrome_128.jpg
# down_1322_jpg.rf.6890f0b1f4a65a4ee66c8f4940200ba5.jpg -> Down_Syndrome_129.jpg
# down_1334_jpg.rf.e8f6cebf90d6e6d9d5d848df342ee1f8.jpg -> Down_Syndrome_130.jpg
# down_1328_jpg.rf.7d01315e25e9fa344e75d2aab54f03f3.jpg -> Down_Syndrome_131.jpg
# down_1336_jpg.rf.6e34cf80e6abd96565859a6186a52056.jpg -> Down_Syndrome_132.jpg
# down_1333_jpg.rf.97b01688047ff7ef9b31897856300dcb.jpg -> Down_Syndrome_133.jpg
# down_132_jpg.rf.3cac3e4421909888c52eddaf03f7a7da.jpg -> Down_Syndrome_134.jpg
# down_1338_jpg.rf.e7c4a6bc5423a1c06f3a53df38e8a444.jpg -> Down_Syndrome_135.jpg
# down_1337_jpg.rf.11c732ac2d36eaf55a9bdc8fac2f5b5e.jpg -> Down_Syndrome_136.jpg
# down_1335_jpg.rf.c9a4f300ab5239be5c0df11df38024e7.jpg -> Down_Syndrome_137.jpg
# down_1327_jpg.rf.ea7b191d13ed9a013b1b028b76323b80.jpg -> Down_Syndrome_138.jpg
# down_1332_jpg.rf.2c7d06b4393b193597205307b6cad607.jpg -> Down_Syndrome_139.jpg
# down_1325_jpg.rf.58807a0a9aa3a858ffe07fd819477c08.jpg -> Down_Syndrome_140.jpg
# down_1346_jpg.rf.d0211d5bddf59f38a1eb6f07e5d30573.jpg -> Down_Syndrome_141.jpg
# down_1347_jpg.rf.9376b2528e3d27db60308981fd4777db.jpg -> Down_Syndrome_142.jpg
# down_1344_jpg.rf.48b3dfd8f7bc94c0f48978e92bbc0562.jpg -> Down_Syndrome_143.jpg
# down_133_jpg.rf.86f31ff882e35eeb966906636219556e.jpg -> Down_Syndrome_144.jpg
# down_1343_jpg.rf.589035b7307ecfcd000a1cd40836f195.jpg -> Down_Syndrome_145.jpg
# down_1341_jpg.rf.87556163f03d3842892c37a41c1e4fe3.jpg -> Down_Syndrome_146.jpg
# down_1340_jpg.rf.611fc7f4235867627e2a0163e1ef877c.jpg -> Down_Syndrome_147.jpg
# down_1339_jpg.rf.de30fc5073187418d786234ab06a8f1d.jpg -> Down_Syndrome_148.jpg
# down_1345_jpg.rf.e21fc5120552483bc3addbe1016fa184.jpg -> Down_Syndrome_149.jpg
# down_1342_jpg.rf.2c2f15245d8ef54c354c25a3971ccdae.jpg -> Down_Syndrome_150.jpg
# down_1350_jpg.rf.1cefb7c7556f955e128c57c0fd7999b3.jpg -> Down_Syndrome_151.jpg
# down_1348_jpg.rf.13bec837402c9ccb391167ace8230156.jpg -> Down_Syndrome_152.jpg
# down_1358_jpg.rf.4c7f5a27eaab35155e52afb989db02ab.jpg -> Down_Syndrome_153.jpg
# down_1356_jpg.rf.91b8db9cde8dd0ff3d1a5efc43fd4a20.jpg -> Down_Syndrome_154.jpg
# down_1359_jpg.rf.8d370602058fd9a1cb5c3e3679c12aa8.jpg -> Down_Syndrome_155.jpg
# down_1349_jpg.rf.fe3d9a2c16f481f0126af690653c89dc.jpg -> Down_Syndrome_156.jpg
# down_1360_jpg.rf.c22328c06f0a236c98fd555570b824e7.jpg -> Down_Syndrome_157.jpg
# down_1353_jpg.rf.1cd808c81b4d00a0a106b7aa1246f534.jpg -> Down_Syndrome_158.jpg
# down_1357_jpg.rf.a17f01b8496b476b55b0bfd88b813a63.jpg -> Down_Syndrome_159.jpg
# down_134_jpg.rf.3bec3be8970e91f1d405e8924d7d0802.jpg -> Down_Syndrome_160.jpg
# down_1362_jpg.rf.c098893199dc9c41b08b6a3d36abb497.jpg -> Down_Syndrome_161.jpg
# down_1381_jpg.rf.000dca0453c752b725336a4caf2fff8a.jpg -> Down_Syndrome_162.jpg
# down_1382_jpg.rf.7a7321fdafa6eb56e4582dd84c1b61a9.jpg -> Down_Syndrome_163.jpg
# down_1379_jpg.rf.4604f4e47c516c00199fe8ac44a02bd8.jpg -> Down_Syndrome_164.jpg
# down_1371_jpg.rf.0b600928a106b0395e1370f28ee90b5a.jpg -> Down_Syndrome_165.jpg
# down_1361_jpg.rf.0ef66d7588facb6d25e0eacb6355a79d.jpg -> Down_Syndrome_166.jpg
# down_136_jpg.rf.f499c3846da768b86869755c7db8bfc6.jpg -> Down_Syndrome_167.jpg
# down_1363_jpg.rf.2365cd525df50f30552d0cd5feca1d51.jpg -> Down_Syndrome_168.jpg
# down_137_jpg.rf.b736b07b8ee7a69702331f3084e14d7b.jpg -> Down_Syndrome_169.jpg
# down_1369_jpg.rf.bbd587c814cbb5482956b3ab433db411.jpg -> Down_Syndrome_170.jpg
# down_1380_jpg.rf.7578bce1bd6a9dcef67df492977c6dc6.jpg -> Down_Syndrome_171.jpg
# down_1392_jpg.rf.032b028ac1c9814766ad4ace027ecd69.jpg -> Down_Syndrome_172.jpg
# down_1389_jpg.rf.aea48efd8c71148779270352830468b9.jpg -> Down_Syndrome_173.jpg
# down_1383_jpg.rf.e5651300450391449791c0389275b221.jpg -> Down_Syndrome_174.jpg
# down_1387_jpg.rf.a5d5053cbd62300346ce3dc48f23aeb7.jpg -> Down_Syndrome_175.jpg
# down_138_jpg.rf.7139e4ff185a133a397e7caa9baf05c3.jpg -> Down_Syndrome_176.jpg
# down_1394_jpg.rf.f0e54b53b64cf1e924fd94c10e6a6636.jpg -> Down_Syndrome_177.jpg
# down_1416_jpg.rf.638d15f7a4979eb72555ee23e37c6118.jpg -> Down_Syndrome_178.jpg
# down_1417_jpg.rf.5fc5ffa3c466eb40f82b1faf66226b3e.jpg -> Down_Syndrome_179.jpg
# down_139_jpg.rf.6cb1390183a1e7f306819693cd29fd8c.jpg -> Down_Syndrome_180.jpg
# down_1395_jpg.rf.d115cfbe796d7b9b610468439f9abf93.jpg -> Down_Syndrome_181.jpg
# down_1402_jpg.rf.1cca8c319258c2d933cadceecb042721.jpg -> Down_Syndrome_182.jpg
# down_13_jpg.rf.3fcd1a34eda801229da899c5b33a1bed.jpg -> Down_Syndrome_183.jpg
# down_1396_jpg.rf.19098e0c13f75afdb84496d76f3dad95.jpg -> Down_Syndrome_184.jpg
# down_1407_jpg.rf.a98cc8389ad7905433169e3f3d4acff5.jpg -> Down_Syndrome_185.jpg
# down_1415_jpg.rf.044fdf2ed3e904097780a25dccfcb75e.jpg -> Down_Syndrome_186.jpg
# down_1406_jpg.rf.1cf834e783985049c44a4cf2298080b5.jpg -> Down_Syndrome_187.jpg
# down_1393_jpg.rf.0e3b06863845c626a2ab02b54fa5c3d2.jpg -> Down_Syndrome_188.jpg
# down_1419_jpg.rf.709c88c393c4517515fd34c38728f2a3.jpg -> Down_Syndrome_189.jpg
# down_1424_jpg.rf.285fb468c4dd37712745277adc4d3014.jpg -> Down_Syndrome_190.jpg
# down_1420_jpg.rf.74794a05e8e59b571e2b4017bb43bfcf.jpg -> Down_Syndrome_191.jpg
# down_142_jpg.rf.7cf092012e1dbf1cb23c14a3ecac322d.jpg -> Down_Syndrome_192.jpg
# down_1432_jpg.rf.9cc258a7da94c6973f458c11299b4bad.jpg -> Down_Syndrome_193.jpg
# down_1430_jpg.rf.41c6ac8c487400af45d2e7b8ab15c81f.jpg -> Down_Syndrome_194.jpg
# down_1418_jpg.rf.b1f3cc00b856c28ae00c54a992512876.jpg -> Down_Syndrome_195.jpg
# down_1421_jpg.rf.9c44b5d7806c21d70409571487416443.jpg -> Down_Syndrome_196.jpg
# down_1434_jpg.rf.28ba9f7f25867fac77e37233304afbde.jpg -> Down_Syndrome_197.jpg
# down_141_jpg.rf.03b58e876759424c133b80b3a51786f3.jpg -> Down_Syndrome_198.jpg
# down_1433_jpg.rf.6b25deed876f654f3011386ead0a842f.jpg -> Down_Syndrome_199.jpg
# down_1440_jpg.rf.173be1f65abea49a991a20aa3d8323d8.jpg -> Down_Syndrome_200.jpg
# down_1449_jpg.rf.285323477dcb42da935f08afbf5fc859.jpg -> Down_Syndrome_201.jpg
# down_143_jpg.rf.6950720d93a43ec60e4e94560bba72d8.jpg -> Down_Syndrome_202.jpg
# down_1442_jpg.rf.e92ed780f3bb42515233d465ed8bc21f.jpg -> Down_Syndrome_203.jpg
# down_1436_jpg.rf.76f9f5bd98b7428c4127a129af14b7fa.jpg -> Down_Syndrome_204.jpg
# down_1438_jpg.rf.2b3b8b2c1b4a147638aba439cda1729a.jpg -> Down_Syndrome_205.jpg
# down_1443_jpg.rf.f1ab2ec8a8990374c28d45e5332b34d0.jpg -> Down_Syndrome_206.jpg
# down_1444_jpg.rf.4790524d203034526e971a25d67e5afa.jpg -> Down_Syndrome_207.jpg
# down_1447_jpg.rf.ba8daad3e26f849f033d798150e80df6.jpg -> Down_Syndrome_208.jpg
# down_1445_jpg.rf.66d3d3b7e835d9d11df11e15e7f8e1a8.jpg -> Down_Syndrome_209.jpg
# down_1437_jpg.rf.b84edd616dc2a790f3dce3eace3d6f42.jpg -> Down_Syndrome_210.jpg
# down_1439_jpg.rf.4bdc006e96e2b9eef52693d9777734a9.jpg -> Down_Syndrome_211.jpg
# down_1483_jpg.rf.4b5710a2965585804f094bf526cb3cc2.jpg -> Down_Syndrome_212.jpg
# down_1467_jpg.rf.57713c9e9091f1705f594dbe3a2bbdb9.jpg -> Down_Syndrome_213.jpg
# down_147_jpg.rf.af673e4831ce582df936e25bd23c0f7b.jpg -> Down_Syndrome_214.jpg
# down_1468_jpg.rf.493a84fa5efc650a4e24825aebb99650.jpg -> Down_Syndrome_215.jpg
# down_146_jpg.rf.5535e656bdbd40355770cb78bc18fcc4.jpg -> Down_Syndrome_216.jpg
# down_1450_jpg.rf.0a4afcb88132ccc3be244ec8e2cd21e6.jpg -> Down_Syndrome_217.jpg
# down_1464_jpg.rf.33a63f26f0ac6410b86f44991e6932c8.jpg -> Down_Syndrome_218.jpg
# down_1469_jpg.rf.c2e195d79d61ff9ef55ea09f7bffe84e.jpg -> Down_Syndrome_219.jpg
# down_1461_jpg.rf.b91ae1b3a0204310b77e8d38efb38fb1.jpg -> Down_Syndrome_220.jpg
# down_1484_jpg.rf.89ff843f205c4c9783a11c28f6c97cd0.jpg -> Down_Syndrome_221.jpg
# down_1482_jpg.rf.f01ffe3ca4d4c3e365e37403f2b24fc3.jpg -> Down_Syndrome_222.jpg
# down_1481_jpg.rf.358dfdf473c21d923cfdee1b07694441.jpg -> Down_Syndrome_223.jpg
# down_1494_jpg.rf.92fc248cd7b08e3d6c2aa38c5c99bfbe.jpg -> Down_Syndrome_224.jpg
# down_1485_jpg.rf.6b218bfe89ca910cc9a5d19b01a123ba.jpg -> Down_Syndrome_225.jpg
# down_1495_jpg.rf.2a484b30659d81ddaba1e5e533f952d6.jpg -> Down_Syndrome_226.jpg
# down_148_jpg.rf.97af56c157f84d2c586e14b9aef35cc1.jpg -> Down_Syndrome_227.jpg
# down_1488_jpg.rf.957edb9471576cc20b0fc6360474f4b9.jpg -> Down_Syndrome_228.jpg
# down_1490_jpg.rf.59eda2b95ceda51772a5f9bc559bb1b3.jpg -> Down_Syndrome_229.jpg
# down_1491_jpg.rf.25e87f35a2252f3157875e05cd49fc11.jpg -> Down_Syndrome_230.jpg
# down_1492_jpg.rf.50831ea1bc31d06c59b72e004dc7e55f.jpg -> Down_Syndrome_231.jpg
# down_1487_jpg.rf.d153f898743b4dc8e187a18b27c7bac5.jpg -> Down_Syndrome_232.jpg
# down_1486_jpg.rf.88e062b134d64b1ed94018e980a57d7b.jpg -> Down_Syndrome_233.jpg
# down_1493_jpg.rf.f8fbd8b8cac7d1ce4ae9082c66b650b1.jpg -> Down_Syndrome_234.jpg
# down_1489_jpg.rf.e8a48e82c9399111266e41812474a509.jpg -> Down_Syndrome_235.jpg
# down_1500_jpg.rf.fb97cfa032342e36d856f173aa7cf3f2.jpg -> Down_Syndrome_236.jpg
# down_1499_jpg.rf.51f263e1a5f57f4447bdc4e8c4832f57.jpg -> Down_Syndrome_237.jpg
# down_1503_jpg.rf.820deed10c081564ea253c7657159c72.jpg -> Down_Syndrome_238.jpg
# down_1504_jpg.rf.698b075106786db7304503cde35e1208.jpg -> Down_Syndrome_239.jpg
# down_1498_jpg.rf.2fa4a4f3d55fadb8ff31754d90f5b559.jpg -> Down_Syndrome_240.jpg
# down_1501_jpg.rf.fdceabac588ae3234131ebda46b05819.jpg -> Down_Syndrome_241.jpg
# down_149_jpg.rf.edc016ac30659607597fa49cd8215736.jpg -> Down_Syndrome_242.jpg
# down_1497_jpg.rf.bd0018dcc9bdf99be90c743ddd3d95e5.jpg -> Down_Syndrome_243.jpg
# down_1505_jpg.rf.508d23d45e0916a9d6a14a14a98ab98b.jpg -> Down_Syndrome_244.jpg
# down_1502_jpg.rf.4011847cfdc376136ca32b3465ed25db.jpg -> Down_Syndrome_245.jpg
# down_1496_jpg.rf.067fa754ff98c297cd89bc590c81dd2a.jpg -> Down_Syndrome_246.jpg
# down_1506_jpg.rf.6f76234ae5a58419c550d3adc09d492c.jpg -> Down_Syndrome_247.jpg
# down_1511_jpg.rf.b5cb501c526c313c72634d1e1c5d1564.jpg -> Down_Syndrome_248.jpg
# down_1512_jpg.rf.8529fa61ebbac2af6833e681d1f4247c.jpg -> Down_Syndrome_249.jpg
# down_1508_jpg.rf.551f4026dbb4f7bfe0fa0ac3fd55af02.jpg -> Down_Syndrome_250.jpg
# down_1510_jpg.rf.da350053ab351ce7bf055b452e41005b.jpg -> Down_Syndrome_251.jpg
# down_1514_jpg.rf.ebc32eaa7ff609d9a0755587734c73b2.jpg -> Down_Syndrome_252.jpg
# down_150_jpg.rf.aefcf400f5f07dcad799fe682851dff4.jpg -> Down_Syndrome_253.jpg
# down_1507_jpg.rf.838512472233e98b7c33f98d0aab24b8.jpg -> Down_Syndrome_254.jpg
# down_1509_jpg.rf.ec7a55b4b442785372bce516272753ca.jpg -> Down_Syndrome_255.jpg
# down_1513_jpg.rf.f285ad0d88c51c403bd24aee153fe09b.jpg -> Down_Syndrome_256.jpg
# down_1515_jpg.rf.28f201baae02fa30a01478f8ed2f8524.jpg -> Down_Syndrome_257.jpg
# down_1517_jpg.rf.b32af776598fa17955f1c0156cdda941.jpg -> Down_Syndrome_258.jpg
# down_1516_jpg.rf.5e2630bc280ace430d42da135fcd067b.jpg -> Down_Syndrome_259.jpg
# down_1518_jpg.rf.834f5f32a14e00360e09b3e5998d7f77.jpg -> Down_Syndrome_260.jpg
# down_1524_jpg.rf.0a3e58669ced319b292882e923072a24.jpg -> Down_Syndrome_261.jpg
# down_1520_jpg.rf.24b2f79f3bae21582553161d9c5c50d4.jpg -> Down_Syndrome_262.jpg
# down_1526_jpg.rf.601316fb926e9c60637e01ccd41461ae.jpg -> Down_Syndrome_263.jpg
# down_154_jpg.rf.0ddaa5a7a5bf21067b90219c2472fedf.jpg -> Down_Syndrome_264.jpg
# down_153_jpg.rf.1f32a5ff435ac3e785d6145c388afeaf.jpg -> Down_Syndrome_265.jpg
# down_1525_jpg.rf.aa29fed04cd54be1474a1c660de988bf.jpg -> Down_Syndrome_266.jpg
# down_1519_jpg.rf.73f7fe99e88522c914104c8af7997a64.jpg -> Down_Syndrome_267.jpg
# down_1521_jpg.rf.f4675133b11ee0eaaebaa4c1e79589f3.jpg -> Down_Syndrome_268.jpg
# down_152_jpg.rf.5adff837e437da5c36ebd00f2a4cb0ff.jpg -> Down_Syndrome_269.jpg
# down_1523_jpg.rf.9dc13e7c0fbdf3379e8decbd15bda487.jpg -> Down_Syndrome_270.jpg
# down_1522_jpg.rf.ce48db7629445ad549fac22beeeca249.jpg -> Down_Syndrome_271.jpg
# down_168_jpg.rf.b37d25999bff2f98bb615dd3ffc054f0.jpg -> Down_Syndrome_272.jpg
# down_158_jpg.rf.5ee6263a82266c1060e742636a46ada1.jpg -> Down_Syndrome_273.jpg
# down_170_jpg.rf.4da3f28141ead2539f34354c4c943761.jpg -> Down_Syndrome_274.jpg
# down_162_jpg.rf.e9f0e27ccedda35bccffcf9ed10a9f95.jpg -> Down_Syndrome_275.jpg
# down_16_jpg.rf.63c22a75849205c52fe7990a6abd4f62.jpg -> Down_Syndrome_276.jpg
# down_157_jpg.rf.680656a40de6bf717000286254ec150a.jpg -> Down_Syndrome_277.jpg
# down_169_jpg.rf.17d30db3ce44e39c246ebf96907fa021.jpg -> Down_Syndrome_278.jpg
# down_164_jpg.rf.dea25d1358d20ea6705a14b0957ca9a4.jpg -> Down_Syndrome_279.jpg
# down_165_jpg.rf.7c94f36e8b5ba9d4bd2bbf11538b1c13.jpg -> Down_Syndrome_280.jpg
# down_166_jpg.rf.b50b5111d91b4e7b2083014dc44e353f.jpg -> Down_Syndrome_281.jpg
# down_179_jpg.rf.4817c281353afab6e4ce9120f9f0cfef.jpg -> Down_Syndrome_282.jpg
# down_173_jpg.rf.e824e9684a67cb46d0813b6776f7950b.jpg -> Down_Syndrome_283.jpg
# down_171_jpg.rf.1cabecad175aeec0850d21653b5586e0.jpg -> Down_Syndrome_284.jpg
# down_178_jpg.rf.06ba8c568530cf2cba8334d1c249a230.jpg -> Down_Syndrome_285.jpg
# down_175_jpg.rf.f0750d8fc0fe51bc6a59cc53665fd8bc.jpg -> Down_Syndrome_286.jpg
# down_180_jpg.rf.4ce209c39fc676c380a68941a19cef4c.jpg -> Down_Syndrome_287.jpg
# down_182_jpg.rf.ea78c9dc4c548d787e3aaaab7f85a331.jpg -> Down_Syndrome_288.jpg
# down_181_jpg.rf.026513a4ed1a1f97bc68d5aa857ff2c9.jpg -> Down_Syndrome_289.jpg
# down_183_jpg.rf.d372ca10b66cee2d557176643cddc521.jpg -> Down_Syndrome_290.jpg
# down_185_jpg.rf.8e65264cf2b1631461f1edc8925b9545.jpg -> Down_Syndrome_291.jpg
# down_192_jpg.rf.2571a7253291f8e6af23d84654ffe894.jpg -> Down_Syndrome_292.jpg
# down_187_jpg.rf.8706a1e52774589bb36fa92f10112800.jpg -> Down_Syndrome_293.jpg
# down_194_jpg.rf.a64f746a10c1ef91e07da0e7b9d435da.jpg -> Down_Syndrome_294.jpg
# down_193_jpg.rf.354a0cf1b77e0dec465ed0aa10d4cab0.jpg -> Down_Syndrome_295.jpg
# down_197_jpg.rf.44e9e825b62785727e4485debc20ef7b.jpg -> Down_Syndrome_296.jpg
# down_205_jpg.rf.ac6b2201436e6cc0005df7c2a61d08c7.jpg -> Down_Syndrome_297.jpg
# down_200_jpg.rf.e357b2ff121c1c5d731732622cf66bae.jpg -> Down_Syndrome_298.jpg
# down_204_jpg.rf.5e4c8188ce3d78e4cc122f33744e3c12.jpg -> Down_Syndrome_299.jpg
# down_208_jpg.rf.b6ba3f476f545a629e65be07ff6445ee.jpg -> Down_Syndrome_300.jpg
# down_202_jpg.rf.6ac844030768bc0d1e83f573c1c14f2f.jpg -> Down_Syndrome_301.jpg
# down_198_jpg.rf.6c2c47aa2aa0377ada8893076258730c.jpg -> Down_Syndrome_302.jpg
# down_199_jpg.rf.699410201ab3ed9e07799494f12dc21e.jpg -> Down_Syndrome_303.jpg
# down_209_jpg.rf.0240cd3ef66f6c4ae828a5c5929d1553.jpg -> Down_Syndrome_304.jpg
# down_217_jpg.rf.aa6bb4042a2ebdcb57a6e68b2d0fa48c.jpg -> Down_Syndrome_305.jpg
# down_220_jpg.rf.f7c1dce40ace4875378cc026cd93710f.jpg -> Down_Syndrome_306.jpg
# down_215_jpg.rf.9a4e7e868c92c4b0175a810119cf4c3d.jpg -> Down_Syndrome_307.jpg
# down_221_jpg.rf.5eb605c93b0b8badf6c99604ca780eac.jpg -> Down_Syndrome_308.jpg
# down_213_jpg.rf.f87a913c2e71c3508efe88867d70e6d7.jpg -> Down_Syndrome_309.jpg
# down_212_jpg.rf.ad52bef202b6e53b17332639fc2b171f.jpg -> Down_Syndrome_310.jpg
# down_210_jpg.rf.5293a68a7e9aeae6837021205cbee73d.jpg -> Down_Syndrome_311.jpg
# down_214_jpg.rf.1946556a5ca1e42f2e8a3c9d891e145f.jpg -> Down_Syndrome_312.jpg
# down_225_jpg.rf.4525b12af73fe2e05c532a23dca4a400.jpg -> Down_Syndrome_313.jpg
# down_226_jpg.rf.eceafd8f0153a4c18f0cbf467af0b27b.jpg -> Down_Syndrome_314.jpg
# down_232_jpg.rf.e3b606f037fd9e7b4d3f0e5a9725cc35.jpg -> Down_Syndrome_315.jpg
# down_224_jpg.rf.2b657a423d722aefbb30f58ac27b6081.jpg -> Down_Syndrome_316.jpg
# down_228_jpg.rf.7aba12190eab0b2c17f2ff924a7afb4d.jpg -> Down_Syndrome_317.jpg
# down_236_jpg.rf.91d22ff1ee6b8f0b1f71dc1058335c8b.jpg -> Down_Syndrome_318.jpg
# down_229_jpg.rf.5fe3c8f7f214f861cf4d096b1f1692d7.jpg -> Down_Syndrome_319.jpg
# down_235_jpg.rf.8e6bb2e9b1c31f26e0e3a066bcc6cfbe.jpg -> Down_Syndrome_320.jpg
# down_227_jpg.rf.b4224c1012a8f784eece78f0e61760be.jpg -> Down_Syndrome_321.jpg
# down_234_jpg.rf.e16e875902bc4c425a83b4790caa587a.jpg -> Down_Syndrome_322.jpg
# down_231_jpg.rf.cee21fe57535a0be02b7fd793f9a6b20.jpg -> Down_Syndrome_323.jpg
# down_22_jpg.rf.28f12188077354f2e37277a03962f5ec.jpg -> Down_Syndrome_324.jpg
# down_237_jpg.rf.9a641b6a5b089dc44b2aeec02e2e9cac.jpg -> Down_Syndrome_325.jpg
# down_248_jpg.rf.7d204c9e6a0302243590edae41570237.jpg -> Down_Syndrome_326.jpg
# down_239_jpg.rf.b2c5783dd9e5ebd6a2b99725479e078f.jpg -> Down_Syndrome_327.jpg
# down_243_jpg.rf.e8507021dcb3a436f6f93f270c2e5011.jpg -> Down_Syndrome_328.jpg
# down_246_jpg.rf.23a42fe41de929b3b8e508a1c1a7bd25.jpg -> Down_Syndrome_329.jpg
# down_238_jpg.rf.ba1d8242c85ee33bc92e12bfa350d995.jpg -> Down_Syndrome_330.jpg
# down_241_jpg.rf.07e1391e513b2a16113b11a689d897fb.jpg -> Down_Syndrome_331.jpg
# down_250_jpg.rf.be1c713b49281c019c8d638b5fd01874.jpg -> Down_Syndrome_332.jpg
# down_249_jpg.rf.2628a674e25a53c53495e0fb421c6c07.jpg -> Down_Syndrome_333.jpg
# down_247_jpg.rf.5fe29ea7dcfaa8705290c2a643cd5a3f.jpg -> Down_Syndrome_334.jpg
# down_245_jpg.rf.e9f686f3ba1d4f3b6640a7e767c36d49.jpg -> Down_Syndrome_335.jpg
# down_244_jpg.rf.e538a6c931c070f1fde4ebe8c52e0c1e.jpg -> Down_Syndrome_336.jpg
# down_256_jpg.rf.d08fba4628247caf8a0dfb3d5331ac27.jpg -> Down_Syndrome_337.jpg
# down_257_jpg.rf.b438b57f023977376bdfbac9a240f600.jpg -> Down_Syndrome_338.jpg
# down_260_jpg.rf.71753774de295636b4210c5ac628a2d9.jpg -> Down_Syndrome_339.jpg
# down_255_jpg.rf.70f319eaa46b11678f586568ee2b58c4.jpg -> Down_Syndrome_340.jpg
# down_262_jpg.rf.dc35d6998fc203e6f767aa4d34ab6867.jpg -> Down_Syndrome_341.jpg
# down_251_jpg.rf.71a0e16e009871c6c6947c714252c085.jpg -> Down_Syndrome_342.jpg
# down_252_jpg.rf.82a99c04812973adb71b1bd0e926e89f.jpg -> Down_Syndrome_343.jpg
# down_259_jpg.rf.563a73ccba58ca79b14007ff9fb5639e.jpg -> Down_Syndrome_344.jpg
# down_253_jpg.rf.3629204e1fa9c147a792b3f4989fff6a.jpg -> Down_Syndrome_345.jpg
# down_254_jpg.rf.c6f1d49e337bd90fc4ba0e9778c55dc3.jpg -> Down_Syndrome_346.jpg
# down_263_jpg.rf.fbe7ab844032c917db00c08058827a33.jpg -> Down_Syndrome_347.jpg
# down_266_jpg.rf.15cbf5f8515445d1ddca03873b6e9ef0.jpg -> Down_Syndrome_348.jpg
# down_267_jpg.rf.717b8de4f8a67d88447350097cf66c7a.jpg -> Down_Syndrome_349.jpg
# down_264_jpg.rf.61f7d4d13769558d70843f5a71b0f8d6.jpg -> Down_Syndrome_350.jpg
# down_269_jpg.rf.000a839f25ac72294dcb99cb1f77c889.jpg -> Down_Syndrome_351.jpg
# down_265_jpg.rf.158f723ca1da8177a981189a3bede772.jpg -> Down_Syndrome_352.jpg
# down_268_jpg.rf.65d89737c825a4cef2bec241f46de982.jpg -> Down_Syndrome_353.jpg
# down_276_jpg.rf.195574ebb6a09f1a7ee6b20afd5e3bf1.jpg -> Down_Syndrome_354.jpg
# down_275_jpg.rf.7aca7fb95ca22d26af1ee49aacf04b26.jpg -> Down_Syndrome_355.jpg
# down_273_jpg.rf.13ad3d793e30ddb7792d8ae5b90db043.jpg -> Down_Syndrome_356.jpg
# down_270_jpg.rf.7c2da50040a65578eec2b91ab26c3ec0.jpg -> Down_Syndrome_357.jpg
# down_272_jpg.rf.3d75e942bbf839cc436627857378c6d2.jpg -> Down_Syndrome_358.jpg
# down_271_jpg.rf.1785218a1a6bbc355488c20ef75279d5.jpg -> Down_Syndrome_359.jpg
# down_274_jpg.rf.fd04f4ef8e1ec9a1d51651956a901305.jpg -> Down_Syndrome_360.jpg
# down_279_jpg.rf.88a4acaac6a84720b19cca77dffaeb40.jpg -> Down_Syndrome_361.jpg
# down_277_jpg.rf.356bc4244c152c4064b43a3bba3d5103.jpg -> Down_Syndrome_362.jpg
# down_278_jpg.rf.dd66c09e8cb8e489afd54de9b4476360.jpg -> Down_Syndrome_363.jpg
# down_280_jpg.rf.ef7b2221dc91c2c35bc7e95ad20edc5a.jpg -> Down_Syndrome_364.jpg
# down_285_jpg.rf.8438829a7f68d8c212d846c593ff2035.jpg -> Down_Syndrome_365.jpg
# down_283_jpg.rf.0d58af179d3d155dd5884833737bafaf.jpg -> Down_Syndrome_366.jpg
# down_286_jpg.rf.e258c609424b22fe9b4d7e401705925a.jpg -> Down_Syndrome_367.jpg
# down_282_jpg.rf.54a3745fbff678a1cd285c745a689a2c.jpg -> Down_Syndrome_368.jpg
# down_289_jpg.rf.157d715042465c4928d1c1c31e0495ad.jpg -> Down_Syndrome_369.jpg
# down_290_jpg.rf.3152c499f53f5638d574aff444f74aaf.jpg -> Down_Syndrome_370.jpg
# down_291_jpg.rf.9da6a6e0a17101d0965c53dc2a1b2868.jpg -> Down_Syndrome_371.jpg
# down_293_jpg.rf.1acc1811a4a9ab79438030c06a8b3341.jpg -> Down_Syndrome_372.jpg
# down_292_jpg.rf.6191dc431f52e17d466e7bbf74717e11.jpg -> Down_Syndrome_373.jpg
# down_288_jpg.rf.b338b9a5938428b0ff24a27dc34c7ef5.jpg -> Down_Syndrome_374.jpg
# down_2_jpg.rf.7970804327f753c59d865a932c971c4b.jpg -> Down_Syndrome_375.jpg
# down_300_jpg.rf.6d820062adee4b9a0a705f04f2fd9483.jpg -> Down_Syndrome_376.jpg
# down_299_jpg.rf.35a46faf233d2a1f2ab7a9e69ce6cee5.jpg -> Down_Syndrome_377.jpg
# down_295_jpg.rf.89c9d9235ad3172e03d4965a80bd096b.jpg -> Down_Syndrome_378.jpg
# down_296_jpg.rf.2dbcd42e642eeefcf1fa461668d28577.jpg -> Down_Syndrome_379.jpg
# down_298_jpg.rf.84f959ea321ac402be548c3578bacb58.jpg -> Down_Syndrome_380.jpg
# down_317_jpg.rf.943e1b13dc14f3456c1f3bc4abf44b16.jpg -> Down_Syndrome_381.jpg
# down_316_jpg.rf.89564aaaa63e0b32efaccafc0ec1b0e0.jpg -> Down_Syndrome_382.jpg
# down_309_jpg.rf.0f3cbb2e6d015aebbb91d0eebca3a245.jpg -> Down_Syndrome_383.jpg
# down_307_jpg.rf.84b848498fdb7fa84862ec172bde8122.jpg -> Down_Syndrome_384.jpg
# down_306_jpg.rf.1cd6933fe48132d3af8f5f3d8f68a0a6.jpg -> Down_Syndrome_385.jpg
# down_331_jpg.rf.4daef417fea5cb8c9c02ae98415dfeaf.jpg -> Down_Syndrome_386.jpg
# down_326_jpg.rf.8e38c8b71573988db13aacb5c19eb146.jpg -> Down_Syndrome_387.jpg
# down_327_jpg.rf.1f23c91a58f1df725271c96a65a7663a.jpg -> Down_Syndrome_388.jpg
# down_32_jpg.rf.69c3ac9f447d8afa691f6b64dcdb9ab9.jpg -> Down_Syndrome_389.jpg
# down_330_jpg.rf.e1bcfb11fc12feb44dfc5cfd16538bce.jpg -> Down_Syndrome_390.jpg
# down_340_jpg.rf.0db23299aad45b80fd67b3ce5f5d379d.jpg -> Down_Syndrome_391.jpg
# down_319_jpg.rf.c5cd4d041081e84d747eadac5763677b.jpg -> Down_Syndrome_392.jpg
# down_343_jpg.rf.c8819e38ad91c046ac00c9f831ca5531.jpg -> Down_Syndrome_393.jpg
# down_345_jpg.rf.f1095805da23bcac31c23584e2b8d3ed.jpg -> Down_Syndrome_394.jpg
# down_354_jpg.rf.38faedc23b11dc4d69641b8c58a5c6dd.jpg -> Down_Syndrome_395.jpg
# down_346_jpg.rf.11ff4e9f2b6c8fedfc62113a37465155.jpg -> Down_Syndrome_396.jpg
# down_355_jpg.rf.66cd1b68091257de3e0b57de22136062.jpg -> Down_Syndrome_397.jpg
# down_358_jpg.rf.d3b3a267a99a83ca94daea0860c93507.jpg -> Down_Syndrome_398.jpg
# down_356_jpg.rf.8df03bdfcd8c053f0b0518ac83575714.jpg -> Down_Syndrome_399.jpg
# down_351_jpg.rf.31b00b3bd4701fc5182376e35a5e4c27.jpg -> Down_Syndrome_400.jpg
# down_353_jpg.rf.dbb42d7fe79207210ba83f0f954f8e2f.jpg -> Down_Syndrome_401.jpg
# down_359_jpg.rf.c439015ade9f1047089ee05b9ba89372.jpg -> Down_Syndrome_402.jpg
# down_367_jpg.rf.08b2fee35bad2382710f29a1f05773f7.jpg -> Down_Syndrome_403.jpg
# down_362_jpg.rf.f96445e1a05908a7fd022c1ad0cd2fc0.jpg -> Down_Syndrome_404.jpg
# down_361_jpg.rf.08b1ecf9e30ef4e48e606bcb545dc9f6.jpg -> Down_Syndrome_405.jpg
# down_365_jpg.rf.ff9a4af3e82835e341f26d9f6e0ffad4.jpg -> Down_Syndrome_406.jpg
# down_366_jpg.rf.48d51f6d9fe288813b57fc9e9e8fa273.jpg -> Down_Syndrome_407.jpg
# down_363_jpg.rf.186baa85610a219e6fd3c5769f9130a6.jpg -> Down_Syndrome_408.jpg
# down_364_jpg.rf.b3abce1bd4926191f153b635758c2abb.jpg -> Down_Syndrome_409.jpg
# down_370_jpg.rf.dc86b9a6d5150217172fbb62230c44ea.jpg -> Down_Syndrome_410.jpg
# down_372_jpg.rf.41478ed8458f6f5e1352de2356b4678f.jpg -> Down_Syndrome_411.jpg
# down_368_jpg.rf.4d9496881b071574690f2484b3e0c10b.jpg -> Down_Syndrome_412.jpg
# down_374_jpg.rf.e26f59e656398356414fc5fe33f67b72.jpg -> Down_Syndrome_413.jpg
# down_371_jpg.rf.f77b4fa71b765e6b199ba2ef48f5f6ca.jpg -> Down_Syndrome_414.jpg
# down_375_jpg.rf.06c6b6b18650274affe874163cf30726.jpg -> Down_Syndrome_415.jpg
# down_37_jpg.rf.e9ea8592257d7771f02393bd39c27b04.jpg -> Down_Syndrome_416.jpg
# down_388_jpg.rf.091c58490a73dc1d1a3ec70195ee2123.jpg -> Down_Syndrome_417.jpg
# down_387_jpg.rf.affd646068566c3f581f8f5d712bcbfd.jpg -> Down_Syndrome_418.jpg
# down_377_jpg.rf.95943fded44654128139fd26d887304f.jpg -> Down_Syndrome_419.jpg
# down_376_jpg.rf.85a74b3846ddcf0120c1094a866830de.jpg -> Down_Syndrome_420.jpg
# down_392_jpg.rf.825f7f237c49993d3b284a2b79ddb801.jpg -> Down_Syndrome_421.jpg
# down_389_jpg.rf.1c1517f5e30fbaa67b15aee9d36b6092.jpg -> Down_Syndrome_422.jpg
# down_390_jpg.rf.9cdccb9abec6e15e8a168ea209222ea7.jpg -> Down_Syndrome_423.jpg
# down_394_jpg.rf.1d8082ea9ded9a04b306c6797bd0d380.jpg -> Down_Syndrome_424.jpg
# down_391_jpg.rf.7d9ff760d5a5ea0eebb97fd48bf7f4ba.jpg -> Down_Syndrome_425.jpg
# down_401_jpg.rf.042cbf7043f803d64915af2c7fc52836.jpg -> Down_Syndrome_426.jpg
# down_403_jpg.rf.f05e63cdf3cd11867eeac56e26e62d32.jpg -> Down_Syndrome_427.jpg
# down_402_jpg.rf.3c37582f68d36a2ad09b168e86688bbd.jpg -> Down_Syndrome_428.jpg
# down_396_jpg.rf.3c179a4710740b8e41d2b0f6be79a27b.jpg -> Down_Syndrome_429.jpg
# down_399_jpg.rf.330585a5ff7cef0a34180fbccb29bb3b.jpg -> Down_Syndrome_430.jpg
# down_395_jpg.rf.ec9d7d79be35a37aa48142bd88284c14.jpg -> Down_Syndrome_431.jpg
# down_404_jpg.rf.528b7282302e62e153f322eda97853c0.jpg -> Down_Syndrome_432.jpg
# down_410_jpg.rf.360eb2810955e74b6aed092bd3207dc6.jpg -> Down_Syndrome_433.jpg
# down_407_jpg.rf.78023abda965755f17806481fe63bddb.jpg -> Down_Syndrome_434.jpg
# down_408_jpg.rf.47b1a1185183d8770feafc887bc05f5f.jpg -> Down_Syndrome_435.jpg
# down_406_jpg.rf.a128f1608c8fcd21f249f04beb45b2dc.jpg -> Down_Syndrome_436.jpg
# down_405_jpg.rf.c15cae3e091d932fc439c998d5d933e3.jpg -> Down_Syndrome_437.jpg
# down_411_jpg.rf.f1f109521569d88eb1f4b6670a2ee4bc.jpg -> Down_Syndrome_438.jpg
# down_415_jpg.rf.5cf3f71b428dde82d60ba5e50823919a.jpg -> Down_Syndrome_439.jpg
# down_419_jpg.rf.12eb26099776b966a98bbbacf108f657.jpg -> Down_Syndrome_440.jpg
# down_418_jpg.rf.b7d84ce1301e5142aa65621d4ffba14e.jpg -> Down_Syndrome_441.jpg
# down_420_jpg.rf.a8ce6594ecf024ecb3daae1c9e2d6557.jpg -> Down_Syndrome_442.jpg
# down_413_jpg.rf.10e8136a8f5b379b684dbc089822b1d3.jpg -> Down_Syndrome_443.jpg
# down_414_jpg.rf.8058eca751e8673edc3e38ad61d2551b.jpg -> Down_Syndrome_444.jpg
# down_423_jpg.rf.e4b94064d5f90f9dbfa535e5777d69f8.jpg -> Down_Syndrome_445.jpg
# down_426_jpg.rf.1ac45f74d0f2df8bf2962ed6a5f1a944.jpg -> Down_Syndrome_446.jpg
# down_432_jpg.rf.30ab6cf8216027a575c6eb1e2d5f8e34.jpg -> Down_Syndrome_447.jpg
# down_421_jpg.rf.8f4b3ab80b3331e672403053d32ced9a.jpg -> Down_Syndrome_448.jpg
# down_427_jpg.rf.750e4e1e7b0f5559a53164f84ad7d133.jpg -> Down_Syndrome_449.jpg
# down_431_jpg.rf.e5688dd4a39d4574b55dac0b5cf0b149.jpg -> Down_Syndrome_450.jpg
# down_422_jpg.rf.904f9eed05a933bbce614313f5327080.jpg -> Down_Syndrome_451.jpg
# down_424_jpg.rf.316d1703050f58d7bc969dd968bf1b11.jpg -> Down_Syndrome_452.jpg
# down_425_jpg.rf.87ee6cd7eaa9d3c81148e6a673ee4b32.jpg -> Down_Syndrome_453.jpg
# down_429_jpg.rf.b5a45b2a1260c7845a2b33bfcb1adbfd.jpg -> Down_Syndrome_454.jpg
# down_428_jpg.rf.b83b36a674f0efae8a00af07b22cb803.jpg -> Down_Syndrome_455.jpg
# down_430_jpg.rf.f5886cbded40f7009155076d2af19bd4.jpg -> Down_Syndrome_456.jpg
# down_446_jpg.rf.80a9fa41e79ca8f6a575cd9e318071eb.jpg -> Down_Syndrome_457.jpg
# down_452_jpg.rf.974b5e6938497308187daaae0be21795.jpg -> Down_Syndrome_458.jpg
# down_441_jpg.rf.d30630210b95a8cfc33a52c077291bc7.jpg -> Down_Syndrome_459.jpg
# down_449_jpg.rf.d7a1569b0e1ebfa600cddb4fb7c38bee.jpg -> Down_Syndrome_460.jpg
# down_451_jpeg.rf.59edea34fd7f490e7ce919b62bba3dd7.jpg -> Down_Syndrome_461.jpg
# down_443_jpg.rf.e9a0d249cd918b375f40809e3f46d7d3.jpg -> Down_Syndrome_462.jpg
# down_433_jpg.rf.ba64910ba15a91af834e371e37cf27d3.jpg -> Down_Syndrome_463.jpg
# down_450_jpg.rf.7d59e9d137bcef58476df928095ce218.jpg -> Down_Syndrome_464.jpg
# down_434_jpg.rf.e1917e49d338ed367751c9d812eb8d61.jpg -> Down_Syndrome_465.jpg
# down_447_jpg.rf.761815aef6559d79b5430c7a843939ae.jpg -> Down_Syndrome_466.jpg
# down_440_jpg.rf.2c406eaf0da6a893bf9abc67ea5f3794.jpg -> Down_Syndrome_467.jpg
# down_442_jpg.rf.51751e8866c9ad36eb36324477a6732e.jpg -> Down_Syndrome_468.jpg
# down_465_jpg.rf.5d2d29dafe5f206ef8dcf81e004d95f4.jpg -> Down_Syndrome_469.jpg
# down_462_jpg.rf.3847a21a4423e025e45c51c0300fc105.jpg -> Down_Syndrome_470.jpg
# down_467_jpg.rf.98298d031a337a921e083386e0da96a1.jpg -> Down_Syndrome_471.jpg
# down_460_jpg.rf.d4f67df85d2e4d315a680c63e93b5233.jpg -> Down_Syndrome_472.jpg
# down_464_jpg.rf.414ba13c2a97bee8e5dace94d484ae49.jpg -> Down_Syndrome_473.jpg
# down_466_jpg.rf.9b2e0864fe11cd8f9f0df304533e04b4.jpg -> Down_Syndrome_474.jpg
# down_463_jpg.rf.a46a9366c32698df33aabf862e28cfa9.jpg -> Down_Syndrome_475.jpg
# down_456_jpg.rf.21f99726fd59207fb12010a8d7e732a7.jpg -> Down_Syndrome_476.jpg
# down_45_jpg.rf.cd4be2a9ea861f8118c1681979dbb4f4.jpg -> Down_Syndrome_477.jpg
# down_461_jpg.rf.07e7e34be6a8b4fa53e55dadb307fa74.jpg -> Down_Syndrome_478.jpg
# down_455_jpg.rf.0e7157258871e4a0adce08d669da9a63.jpg -> Down_Syndrome_479.jpg
# down_469_jpg.rf.4edcc18991f82940223894337e135e84.jpg -> Down_Syndrome_480.jpg
# down_472_jpg.rf.b32609962555c4ff3c7acf6c1d2e055a.jpg -> Down_Syndrome_481.jpg
# down_470_jpg.rf.7430ec9f49d2d94bcd6ef1fdedb6e63d.jpg -> Down_Syndrome_482.jpg
# down_468_jpg.rf.c5d7b85efaea5806ada047376c425fd5.jpg -> Down_Syndrome_483.jpg
# down_471_jpg.rf.cc364db4ed8c242a726e4d219844281b.jpg -> Down_Syndrome_484.jpg
# down_500_jpg.rf.2131e9924f96a146f7cf5b3c72c9cacb.jpg -> Down_Syndrome_485.jpg
# down_496_jpg.rf.91a72b31abbe5be94e1fd622291dd8f2.jpg -> Down_Syndrome_486.jpg
# down_501_jpg.rf.f04d59e32ddc7d5981afcd2c6e30d581.jpg -> Down_Syndrome_487.jpg
# down_50_jpg.rf.7c0b0a4b83e3e19b5fe4c375143ea507.jpg -> Down_Syndrome_488.jpg
# down_509_jpg.rf.8b7e306a27443c5600d4a5f22faaef80.jpg -> Down_Syndrome_489.jpg
# down_506_jpg.rf.9ab7d25e389f37e6d006d27b5f7acebb.jpg -> Down_Syndrome_490.jpg
# down_478_jpg.rf.5135d1dc59f517fe6f064e946313dbaf.jpg -> Down_Syndrome_491.jpg
# down_507_jpg.rf.b1acda084be454cfd40cfd65cbf0feda.jpg -> Down_Syndrome_492.jpg
# down_519_jpg.rf.eed0b87de295ecbff11240245381dbd9.jpg -> Down_Syndrome_493.jpg
# down_521_jpg.rf.76e2a93821d161b223d74df76d6bc0bb.jpg -> Down_Syndrome_494.jpg
# down_526_jpg.rf.48020d8225d4be7533a507a8818d294a.jpg -> Down_Syndrome_495.jpg
# down_529_jpg.rf.3f37791f04861ae83da415782d8f6510.jpg -> Down_Syndrome_496.jpg
# down_510_jpg.rf.cc13f9c9b5303e3518f43ee41aa2f905.jpg -> Down_Syndrome_497.jpg
# down_517_jpg.rf.178488dbc2e8b064866538a71fff2158.jpg -> Down_Syndrome_498.jpg
# down_527_jpg.rf.d213a8a0c6a44a476b5ce5773c6af3b1.jpg -> Down_Syndrome_499.jpg
# down_518_jpg.rf.5feb1a237efd628b27f0567e7f9b0904.jpg -> Down_Syndrome_500.jpg
# down_512_jpg.rf.d6861507a9cb51eeadd914eb97a955bb.jpg -> Down_Syndrome_501.jpg
# down_513_jpg.rf.ea968afc6f98539e75fb88ba9c580363.jpg -> Down_Syndrome_502.jpg
# down_531_jpg.rf.40d3835b29c1f1ee1ef419ac4b09c0bd.jpg -> Down_Syndrome_503.jpg
# down_514_jpg.rf.05946c1573f64448722cbd2032e5cd5e.jpg -> Down_Syndrome_504.jpg
# down_546_jpg.rf.80397b2b2a8c01117ecaea0a0b688d8c.jpg -> Down_Syndrome_505.jpg
# down_548_jpg.rf.9eac5e737fbf4a80a74bdccfe8e43070.jpg -> Down_Syndrome_506.jpg
# down_534_jpg.rf.a0b7a4300686fd29ce72256253736bcd.jpg -> Down_Syndrome_507.jpg
# down_541_jpg.rf.c14938ca0f3382e3192e67f0d78dd0c1.jpg -> Down_Syndrome_508.jpg
# down_540_jpg.rf.b2653d3d2a1bec17dea08083b57a7106.jpg -> Down_Syndrome_509.jpg
# down_538_jpg.rf.278147262c17012828e3a2e349a03946.jpg -> Down_Syndrome_510.jpg
# down_545_jpg.rf.01830c22d31db04072362acdbdd7602b.jpg -> Down_Syndrome_511.jpg
# down_547_jpg.rf.8482987b60892e3d49be88e3b2a69f58.jpg -> Down_Syndrome_512.jpg
# down_539_jpg.rf.e2705b7c7ed07254fd0c0dd1b07f01ae.jpg -> Down_Syndrome_513.jpg
# down_533_jpg.rf.75c3968f128269578a9f4d7b929737b6.jpg -> Down_Syndrome_514.jpg
# down_549_jpg.rf.f4255a3cce47252e4ee8403f992e8985.jpg -> Down_Syndrome_515.jpg
# down_544_jpg.rf.6fd9b696b39203552fc4d28e237aa8e3.jpg -> Down_Syndrome_516.jpg
# down_550_jpg.rf.a39dbf7af1765539fefc257b101ee431.jpg -> Down_Syndrome_517.jpg
# down_552_jpg.rf.28c7cf847479a70709eb9145db8a9530.jpg -> Down_Syndrome_518.jpg
# down_553_jpg.rf.51a9a1f87e576dd6372741d3c4bbad1f.jpg -> Down_Syndrome_519.jpg
# down_558_jpg.rf.be5ca55829bca0694e13602a26613df5.jpg -> Down_Syndrome_520.jpg
# down_555_jpg.rf.a52c1ab13720bd0e0326085a4cd52902.jpg -> Down_Syndrome_521.jpg
# down_556_jpg.rf.3847ace2a77383f3ea699d002825d603.jpg -> Down_Syndrome_522.jpg
# down_562_jpg.rf.30c512b35a40ac2a18c6c7b2eb8b3856.jpg -> Down_Syndrome_523.jpg
# down_557_jpg.rf.a0c4f37edb5b4c198050abcdc6bc2582.jpg -> Down_Syndrome_524.jpg
# down_559_jpg.rf.5576d6007cbda5f24ec6c067e33630fa.jpg -> Down_Syndrome_525.jpg
# down_551_jpg.rf.bd87b65d320f8841a1d65971e824f134.jpg -> Down_Syndrome_526.jpg
# down_564_jpg.rf.1725f23f6b0fb9ac885b5a860fb91afc.jpg -> Down_Syndrome_527.jpg
# down_563_jpg.rf.39193799004302d438ef745dec9887fd.jpg -> Down_Syndrome_528.jpg
# down_56_jpeg.rf.f3436eb490cd35aba343529176684237.jpg -> Down_Syndrome_529.jpg
# down_581_jpg.rf.a5718282160a87569a426d6bbc1f91fc.jpg -> Down_Syndrome_530.jpg
# down_578_jpg.rf.dc4b8251dd49264c19d915da80ebe9d4.jpg -> Down_Syndrome_531.jpg
# down_576_jpg.rf.be4e77a192caf539380bbc04c2b5a026.jpg -> Down_Syndrome_532.jpg
# down_565_jpg.rf.201d54b2975125453deb48b3cd86ff30.jpg -> Down_Syndrome_533.jpg
# down_579_jpg.rf.ae65648e989dbf0f587a7ddc1c9cc3d5.jpg -> Down_Syndrome_534.jpg
# down_575_jpg.rf.21b35f1c3496e5a25fe39150cb51eadd.jpg -> Down_Syndrome_535.jpg
# down_569_jpg.rf.72d9400b4738e09215877964389178a2.jpg -> Down_Syndrome_536.jpg
# down_567_jpg.rf.7aca375dd014303d1f93af8f7a9a9533.jpg -> Down_Syndrome_537.jpg
# down_568_jpg.rf.21ed38cc1f3faabe40fe8ce3af535cf3.jpg -> Down_Syndrome_538.jpg
# down_584_jpg.rf.150f73c3cc9bafe48b7af6db28e716fa.jpg -> Down_Syndrome_539.jpg
# down_611_jpg.rf.345f4bdcf99d474e2b3dc169b75eb429.jpg -> Down_Syndrome_540.jpg
# down_613_jpg.rf.b02281c9be5b47cba76cec56f27fce16.jpg -> Down_Syndrome_541.jpg
# down_59_jpg.rf.7eb9b8fc704d0218c954c75864df1128.jpg -> Down_Syndrome_542.jpg
# down_592_jpg.rf.4a9ebe0cef006a74056480e1befd90d8.jpg -> Down_Syndrome_543.jpg
# down_591_jpg.rf.e9c011c8a108fc4c9f335e3069d48ab6.jpg -> Down_Syndrome_544.jpg
# down_610_jpg.rf.0be0ea6a3b60bf97c32d6576e0fbf4fc.jpg -> Down_Syndrome_545.jpg
# down_598_jpg.rf.cdd053a5e20bb68e46656e42195cc2d2.jpg -> Down_Syndrome_546.jpg
# down_596_jpg.rf.6688dceeba408dbcaff8a7e2b02e67df.jpg -> Down_Syndrome_547.jpg
# down_5_png.rf.68b051dfbf1750704abbb0980953116e.jpg -> Down_Syndrome_548.jpg
# down_599_jpg.rf.f23a9065c322a4f5180e238e5afd0515.jpg -> Down_Syndrome_549.jpg
# down_604_jpg.rf.8b31a9654c70adf9d659dfa8d2a0e2d8.jpg -> Down_Syndrome_550.jpg
# down_595_jpg.rf.6f9885ef57505eb2238f4432bf333c42.jpg -> Down_Syndrome_551.jpg
# down_627_jpg.rf.b9a582bdfb09786117b6d02c07a31172.jpg -> Down_Syndrome_552.jpg
# down_615_jpg.rf.465b680094d41f8b003d496222a44d94.jpg -> Down_Syndrome_553.jpg
# down_625_jpg.rf.5a731a9f28b43771db88721b22a54708.jpg -> Down_Syndrome_554.jpg
# down_634_jpg.rf.89e3cc25e6a8eba194c9bf1265a232c9.jpg -> Down_Syndrome_555.jpg
# down_630_jpg.rf.7fc618f8882784de890db52df05d511e.jpg -> Down_Syndrome_556.jpg
# down_629_jpg.rf.50fc7be58c3ee013b10f557442e272c7.jpg -> Down_Syndrome_557.jpg
# down_622_jpg.rf.8ccbd3429a84eb1a92412063fefc24aa.jpg -> Down_Syndrome_558.jpg
# down_626_jpg.rf.7cf39d5714ea4f55a2e2c4f2b03fd19a.jpg -> Down_Syndrome_559.jpg
# down_616_jpg.rf.85f682d6247c7be01cf3be8b3a9a5c64.jpg -> Down_Syndrome_560.jpg
# down_653_jpg.rf.f27d137b1e6a20eb0be09a45dd397c13.jpg -> Down_Syndrome_561.jpg
# down_647_jpg.rf.b106afd7940322927a49d3c762b85d4e.jpg -> Down_Syndrome_562.jpg
# down_640_jpg.rf.f672d6e082451125b5864c5daec32db8.jpg -> Down_Syndrome_563.jpg
# down_639_jpg.rf.60790e7cf22477fb83c36d4cb58c2888.jpg -> Down_Syndrome_564.jpg
# down_646_jpg.rf.7a5d6ac68f4f61df26f78c8486379cdc.jpg -> Down_Syndrome_565.jpg
# down_645_jpg.rf.71366a98256a01c0a5bd6ea1786928b9.jpg -> Down_Syndrome_566.jpg
# down_635_jpg.rf.f634056ed5c2fd37b861ad99732c36ba.jpg -> Down_Syndrome_567.jpg
# down_656_jpg.rf.dbbe31ea33203b2fc6191de7a9238152.jpg -> Down_Syndrome_568.jpg
# down_65_jpg.rf.fb0ba5697ebfc32423bb611e7d22dcea.jpg -> Down_Syndrome_569.jpg
# down_659_jpg.rf.39d58dc8162347b8910fe5611c88e4b9.jpg -> Down_Syndrome_570.jpg
# down_658_jpg.rf.40034a3699a831fb3aafb32c80d4e56c.jpg -> Down_Syndrome_571.jpg
# down_655_jpg.rf.57f4438c13c3fc9f44ec4eba474fbaef.jpg -> Down_Syndrome_572.jpg
# down_669_jpg.rf.a8b5a888eb33a71f21b12d0361b33c31.jpg -> Down_Syndrome_573.jpg
# down_672_jpg.rf.604934cc57413c81ce8b088799d8ea9b.jpg -> Down_Syndrome_574.jpg
# down_677_jpg.rf.67d66db42c567dd674b30b5084804862.jpg -> Down_Syndrome_575.jpg
# down_680_jpg.rf.241959b708893d40a8b6c87b633ca148.jpg -> Down_Syndrome_576.jpg
# down_67_png.rf.bbed498c94a08907c70364161c2c715b.jpg -> Down_Syndrome_577.jpg
# down_667_jpg.rf.766b1ce9b0823afffd8200f14c483801.jpg -> Down_Syndrome_578.jpg
# down_661_jpg.rf.272ba8fae017d5f6ea4ccc32cd9faff6.jpg -> Down_Syndrome_579.jpg
# down_681_jpg.rf.4e2e2555bb63f90db7120658f74eb435.jpg -> Down_Syndrome_580.jpg
# down_664_jpg.rf.088cd8d0b2a971e2b69738d060038fcb.jpg -> Down_Syndrome_581.jpg
# down_662_jpg.rf.b6f2c49cac309e796ed4221121170cb1.jpg -> Down_Syndrome_582.jpg
# down_683_jpg.rf.52c277d7e8f50df6f249e1a6f6c4cba5.jpg -> Down_Syndrome_583.jpg
# down_692_jpg.rf.8ab4fd1737f69de69dddd2e34588cd16.jpg -> Down_Syndrome_584.jpg
# down_688_jpg.rf.479db635e1c354ab2727895e027dfd93.jpg -> Down_Syndrome_585.jpg
# down_685_jpg.rf.edfe21263f3d02d1104aa4f429e6e5bd.jpg -> Down_Syndrome_586.jpg
# down_687_jpg.rf.581f26df16364fae3e37c76cccaf068a.jpg -> Down_Syndrome_587.jpg
# down_689_jpg.rf.284d50453117d6bd613e1875627ea97f.jpg -> Down_Syndrome_588.jpg
# down_690_jpg.rf.c64930681da8b35a577f47a9d6134d35.jpg -> Down_Syndrome_589.jpg
# down_695_jpg.rf.1e2c0669074b0c5928593480d97a66cb.jpg -> Down_Syndrome_590.jpg
# down_696_jpg.rf.cdd7f2b94e22b1bd413512fe64b65c1f.jpg -> Down_Syndrome_591.jpg
# down_682_jpg.rf.4c563b88eb9b598247fd8578f7cf3558.jpg -> Down_Syndrome_592.jpg
# down_684_jpg.rf.f375a5f70abc5ade85a738ba2f1b88d4.jpg -> Down_Syndrome_593.jpg
# down_691_jpg.rf.b18a927da599ae1bee6c40d4587f4997.jpg -> Down_Syndrome_594.jpg
# down_6_jpg.rf.f6992c655d8cdc9e721d7b3ae8359b66.jpg -> Down_Syndrome_595.jpg
# down_705_jpg.rf.1f6a9090bdd545d7a9285bd5271edfab.jpg -> Down_Syndrome_596.jpg
# down_69_jpg.rf.ba66fccb6db61e76f1866cb72d7d4fc5.jpg -> Down_Syndrome_597.jpg
# down_697_jpg.rf.2c890392edf3429df5123dd6736e0448.jpg -> Down_Syndrome_598.jpg
# down_701_jpg.rf.efdb67e4d959211d8f9cf76881a93dfd.jpg -> Down_Syndrome_599.jpg
# down_699_jpg.rf.12a10f587312424d40dbfcb8d5b77590.jpg -> Down_Syndrome_600.jpg
# down_702_jpg.rf.046246d6b2441a378c47057c8f77e3e6.jpg -> Down_Syndrome_601.jpg
# down_700_jpg.rf.85af97c91888318f0dd8228286aaa54f.jpg -> Down_Syndrome_602.jpg
# down_707_jpg.rf.85c0d6f937ba69a350ea7f492458d1d1.jpg -> Down_Syndrome_603.jpg
# down_713_jpg.rf.afd52c65af465262510ce792b2e73a57.jpg -> Down_Syndrome_604.jpg
# down_714_jpg.rf.e4a451ad168c848a09db6364b06afcd7.jpg -> Down_Syndrome_605.jpg
# down_712_jpg.rf.e4172860cb27933e44fea3f8a0acbf8c.jpg -> Down_Syndrome_606.jpg
# down_708_jpg.rf.43bb90dfbf1a774e90de0fdbe0146cd0.jpg -> Down_Syndrome_607.jpg
# down_711_jpg.rf.1012b2754b813625a627aa6041f09287.jpg -> Down_Syndrome_608.jpg
# down_706_jpg.rf.7d6d28264482c0b4ad4de1c87885428c.jpg -> Down_Syndrome_609.jpg
# down_710_jpg.rf.5df53700a8db2f84f954b433f1a7ced3.jpg -> Down_Syndrome_610.jpg
# down_716_jpg.rf.5988be007feb93e212d8aec6dab5dba1.jpg -> Down_Syndrome_611.jpg
# down_715_jpg.rf.e14453043884d1fccbeb307ad13668df.jpg -> Down_Syndrome_612.jpg
# ...
# healty_22_jpg.rf.92d5a7ecb4909ed010d8119358787bb8.jpg -> Healthy_405.jpg
# healty_224_jpg.rf.aafba916142661d3d719d568b8326d9b.jpg -> Healthy_406.jpg
# healty_225_jpg.rf.d96005b27687f2970a8275a219116cb7.jpg -> Healthy_407.jpg
# healty_221_jpg.rf.e5bbe11792e5bb06b2456031c03bf88a.jpg -> Healthy_408.jpg
# healty_227_jpg.rf.b88def5e2840abe40574c2dbca64dedb.jpg -> Healthy_409.jpg
# healty_230_jpg.rf.fb3c1150bc764cd166a50a67bcc925e6.jpg -> Healthy_410.jpg
# healty_223_jpg.rf.c176002082ba4b3a4c97d2aff8f868b0.jpg -> Healthy_411.jpg
# healty_232_jpg.rf.3d6f2772c04dad0cafdce6ea9155dcf3.jpg -> Healthy_412.jpg
# healty_238_jpg.rf.66739d4a9392cceaefea0f1f11fd4774.jpg -> Healthy_413.jpg
# healty_234_jpg.rf.a810580f974c59cc6f654d9f3a90c2f9.jpg -> Healthy_414.jpg
# healty_243_jpg.rf.053e14e0fe27840e79145dcf5c324b64.jpg -> Healthy_415.jpg
# healty_231_jpg.rf.f491c93e7435c30a095a76567b3bb865.jpg -> Healthy_416.jpg
# healty_235_jpg.rf.021540b4c981f4de7385520cd92a1fa2.jpg -> Healthy_417.jpg
# healty_242_jpg.rf.ee3c292d450dded8fecc9ed5b3e45cb5.jpg -> Healthy_418.jpg
# healty_23_jpg.rf.05337ba5b37d10f3a057d6767d495d9f.jpg -> Healthy_419.jpg
# healty_233_jpg.rf.bdcad657f9e9ab2f4db3afeba9675876.jpg -> Healthy_420.jpg
# healty_236_jpg.rf.00adcf886cba3f883c18030cced8a658.jpg -> Healthy_421.jpg
# healty_244_jpg.rf.faf3c53abff9d56dec41def36b4e7aa6.jpg -> Healthy_422.jpg
# healty_253_jpg.rf.03263f51aa1aad8602eccefe899f79cd.jpg -> Healthy_423.jpg
# healty_245_jpg.rf.963c9e459dae6f9c2b9b0002b2ea1080.jpg -> Healthy_424.jpg
# healty_247_jpg.rf.5d26f88b38dd096bbe4cb4e58f223d2f.jpg -> Healthy_425.jpg
# healty_248_jpg.rf.7dead86e94353116eed91530c779fd19.jpg -> Healthy_426.jpg
# healty_246_jpg.rf.9c25bb77afc367eb3e58ddd46dd2292f.jpg -> Healthy_427.jpg
# healty_25_jpg.rf.a7eb0837ceefa49b4e8dfafc2946e2f9.jpg -> Healthy_428.jpg
# healty_260_jpg.rf.c68a1893e582cf933988d48f36d93e0f.jpg -> Healthy_429.jpg
# healty_264_jpg.rf.1d8267382ff78d9f3aff8e2fd270f2e0.jpg -> Healthy_430.jpg
# healty_255_jpg.rf.73cc6325799000693b5c16d8043f862b.jpg -> Healthy_431.jpg
# healty_261_jpg.rf.8b5e1930afc96df531eb2322c04e53ba.jpg -> Healthy_432.jpg
# healty_256_jpg.rf.2314e8d95c4d5604048e29f1c8733cdb.jpg -> Healthy_433.jpg
# healty_259_jpg.rf.f0492b475bbe87671e92af4da37754c6.jpg -> Healthy_434.jpg
# healty_257_jpg.rf.1b3bae93f178f6b3445f028c64e910e1.jpg -> Healthy_435.jpg
# healty_270_jpg.rf.f760a8ab4e58946e71de45702d863db3.jpg -> Healthy_436.jpg
# healty_279_jpg.rf.a89cc12ae0c474d98c2068929208a1d8.jpg -> Healthy_437.jpg
# healty_268_jpg.rf.e4fddcb678527114977fb2e32d2e0900.jpg -> Healthy_438.jpg
# healty_273_jpg.rf.3426166f18e76fb065bb25b2260a5bd4.jpg -> Healthy_439.jpg
# healty_27_jpg.rf.ba5a6d06629dda98958e841b9e71ff16.jpg -> Healthy_440.jpg
# healty_272_jpg.rf.b1bee5fea450f9c35c402aa6559b594b.jpg -> Healthy_441.jpg
# healty_274_jpg.rf.fe5dae36ef2f07dbc6a4833a68d158f5.jpg -> Healthy_442.jpg
# healty_286_jpg.rf.3b25fca228e7863290519062e647b9e1.jpg -> Healthy_443.jpg
# healty_282_jpg.rf.e4a7a32d0623dea3f162e97d5d281666.jpg -> Healthy_444.jpg
# healty_291_jpg.rf.250ea00644edad47d962ec694ce949ae.jpg -> Healthy_445.jpg
# healty_28_jpg.rf.008064b7f32ec15902b1bba7dc46a494.jpg -> Healthy_446.jpg
# healty_284_jpg.rf.7281ab7aeb9effa3f124a797c57526c8.jpg -> Healthy_447.jpg
# healty_303_jpg.rf.4c7ccb080e626af5d236611a37515d41.jpg -> Healthy_448.jpg
# healty_292_jpg.rf.26cc2f36cd5443619f0fcaa019f5b829.jpg -> Healthy_449.jpg
# healty_29_jpg.rf.c78007d4472fbaca6969e217fc605169.jpg -> Healthy_450.jpg
# healty_296_jpg.rf.2df1bc96136c27544164b3e973610e05.jpg -> Healthy_451.jpg
# healty_293_jpg.rf.f306e3d08c90416bd85bfacc0a9ca9aa.jpg -> Healthy_452.jpg
# healty_301_jpg.rf.36fe745fc803341b2ab7201f84b9eec8.jpg -> Healthy_453.jpg
# healty_304_jpg.rf.8530c43d5c7616598a8567593701dba1.jpg -> Healthy_454.jpg
# healty_311_jpg.rf.733059d03f9489339daa1eb3c654c7e1.jpg -> Healthy_455.jpg
# healty_306_jpg.rf.00f15755bd0a82b36f81b55dfd822363.jpg -> Healthy_456.jpg
# healty_315_jpg.rf.157e9e5e3a54e07fb71d010abb995e6b.jpg -> Healthy_457.jpg
# healty_312_jpg.rf.045efa6a0af28436e7f90f493898dcf9.jpg -> Healthy_458.jpg
# healty_316_jpg.rf.f7b0f6624a763ec0efd94f7bd99fa648.jpg -> Healthy_459.jpg
# healty_326_jpg.rf.8ee5e77f5e0b0a81993e248ecd1bfa5e.jpg -> Healthy_460.jpg
# healty_317_jpg.rf.64ec23903494df77630104a40c7f4463.jpg -> Healthy_461.jpg
# healty_328_jpg.rf.05769e1f5be6e0e392caa0a811c59d97.jpg -> Healthy_462.jpg
# healty_333_jpg.rf.93d3f2e9084a1c1f724225136fdaa3f8.jpg -> Healthy_463.jpg
# healty_350_jpg.rf.b40cbda72ffeed39d38e7893821fd053.jpg -> Healthy_464.jpg
# healty_335_jpg.rf.208d14da180b103628f9be815d2031e1.jpg -> Healthy_465.jpg
# healty_336_jpg.rf.3694cc97a7b56b45e33db278be8fa148.jpg -> Healthy_466.jpg
# healty_340_jpg.rf.9d72670aa51be53896b1696bd6faaab3.jpg -> Healthy_467.jpg
# healty_349_jpg.rf.0e7cdae4618adf404a7630399f858b38.jpg -> Healthy_468.jpg
# healty_347_jpg.rf.73c7121e47bca5afb994b05ef22fec27.jpg -> Healthy_469.jpg
# healty_33_jpg.rf.085a686496fd3e5110c39a5ae14464b1.jpg -> Healthy_470.jpg
# healty_357_jpg.rf.235b85578e924165ff50c426d121fb31.jpg -> Healthy_471.jpg
# healty_360_jpg.rf.b58e0c2ba13faadf55c11f742e8c739e.jpg -> Healthy_472.jpg
# healty_359_jpg.rf.0971b591233b43289d96e565c2c51f27.jpg -> Healthy_473.jpg
# healty_361_jpg.rf.fb1a814c5df808fe0314c426a045a34d.jpg -> Healthy_474.jpg
# healty_353_jpg.rf.59edf539d9b4c134ed13c2a16961e09f.jpg -> Healthy_475.jpg
# healty_354_jpg.rf.2125249ec7b989eea3605debaa1ccbe3.jpg -> Healthy_476.jpg
# healty_363_jpg.rf.b26e723878124b9aab86444ca6093b2d.jpg -> Healthy_477.jpg
# healty_37_jpg.rf.b7ee34ac08ef1fec8cafe2c297e83059.jpg -> Healthy_478.jpg
# healty_368_jpg.rf.71a3adf575481e901cbb1612238495e1.jpg -> Healthy_479.jpg
# healty_376_jpg.rf.0ea1ca07a2d00f9469283d052997ef3a.jpg -> Healthy_480.jpg
# healty_378_jpg.rf.bc69312fb9d213eca1f4693878ccd0bf.jpg -> Healthy_481.jpg
# healty_380_jpg.rf.4da8122e0dbdf49f8263006f6943d139.jpg -> Healthy_482.jpg
# healty_387_jpg.rf.63f84c8254f48a3ea28d3aeb5e61fdde.jpg -> Healthy_483.jpg
# healty_385_jpg.rf.6c603501f7f59960e0f1606fbe888601.jpg -> Healthy_484.jpg
# healty_388_jpg.rf.7a7ebe6b720b73578b6996a36ba3fd09.jpg -> Healthy_485.jpg
# healty_39_jpg.rf.9179c049b0c1db1b23141516a3ef9cbf.jpg -> Healthy_486.jpg
# healty_399_jpg.rf.5324caeaf2c9ae66aadf834c2bf918c1.jpg -> Healthy_487.jpg
# healty_405_jpg.rf.22d8b16384a0c0fae07278adc1e047a2.jpg -> Healthy_488.jpg
# healty_398_jpg.rf.8b163687bffc7feb2c2cc97a8401fcc1.jpg -> Healthy_489.jpg
# healty_411_jpg.rf.d436002e347f59e460f4a546bf2cf807.jpg -> Healthy_490.jpg
# healty_409_jpg.rf.074fdc7a1cdbebcf130ce0509b6c7a6f.jpg -> Healthy_491.jpg
# healty_417_jpg.rf.de6baee6d4ff3e36f26f68bc671cb8f6.jpg -> Healthy_492.jpg
# healty_439_jpg.rf.23dbd8a22a4d29e856d27062219f32d3.jpg -> Healthy_493.jpg
# healty_436_jpg.rf.57341e8427fc359bf9aa5384224dd922.jpg -> Healthy_494.jpg
# healty_43_jpg.rf.dc6d36d0111cada3e929b5450678dfef.jpg -> Healthy_495.jpg
# healty_426_jpg.rf.5476b6f409da417476d16db39b235ee7.jpg -> Healthy_496.jpg
# healty_42_jpg.rf.cfad7160097c93f1875b413964c89ad4.jpg -> Healthy_497.jpg
# healty_444_jpg.rf.899395650dc2dfd514dcbfade747eef2.jpg -> Healthy_498.jpg
# healty_448_jpg.rf.c9e25ab67af4bb7c45b3ea083d9a01f6.jpg -> Healthy_499.jpg
# healty_442_jpg.rf.bdcb21789a577082d62b6bc1a1cdc83c.jpg -> Healthy_500.jpg
# healty_447_jpg.rf.bdaead1be94f3320ee37decce65f809b.jpg -> Healthy_501.jpg
# healty_468_jpg.rf.f3d2ae55c774c10412773ac97e016e6f.jpg -> Healthy_502.jpg
# healty_46_jpg.rf.d53807546b9e8492419bca10d48cef69.jpg -> Healthy_503.jpg
# healty_471_jpg.rf.8b106a4cc4c65b6e67b23f081749e4aa.jpg -> Healthy_504.jpg
# healty_47_jpg.rf.4ccedccaef1a17f9730330017eb1173f.jpg -> Healthy_505.jpg
# healty_483_jpg.rf.89b854bd9324a068d2b541a2b5375893.jpg -> Healthy_506.jpg
# healty_482_jpg.rf.e465db997f7303c5af83bd2656cb1905.jpg -> Healthy_507.jpg
# healty_488_jpg.rf.1eadad520ff94afaa90b51bb75b4f50e.jpg -> Healthy_508.jpg
# healty_481_jpg.rf.f2d2a92c246f745f617bcad8313af051.jpg -> Healthy_509.jpg
# healty_484_jpg.rf.3205cb151429ea76cd57ce6b6018f3b2.jpg -> Healthy_510.jpg
# healty_485_jpg.rf.e6d2b04fc7ad790fb953214b9fc001fc.jpg -> Healthy_511.jpg
# healty_487_jpg.rf.56197407e8cf8a023de984d55fb31ab8.jpg -> Healthy_512.jpg
# healty_495_jpg.rf.a491ef17b1ab1ac20ebcad6289692b55.jpg -> Healthy_513.jpg
# healty_503_jpg.rf.ff1ee92b0cb707719a996e78ca20764b.jpg -> Healthy_514.jpg
# healty_511_jpg.rf.d548cd44ff4120077bcc5bbd6b17afc5.jpg -> Healthy_515.jpg
# healty_508_jpg.rf.ca446ac47104562dd05e5bbaa25d6a3f.jpg -> Healthy_516.jpg
# healty_507_jpg.rf.f516ed2caa409f461e516b5349b4ac5d.jpg -> Healthy_517.jpg
# healty_515_jpg.rf.346b0f2dae1519e6c3dbdc639d553300.jpg -> Healthy_518.jpg
# healty_516_jpg.rf.2e2bfd67f94777935030dfd9d20a1088.jpg -> Healthy_519.jpg
# healty_51_jpg.rf.fbda57877aaa40a80a7bf49cce6ec2be.jpg -> Healthy_520.jpg
# healty_525_jpg.rf.eeacf2c60c8c75cd38eb32e73762fadd.jpg -> Healthy_521.jpg
# healty_526_jpg.rf.f45b24462dcfb6caaa4a9658ac5d4d81.jpg -> Healthy_522.jpg
# healty_533_jpg.rf.6718d2ae1d3058c5c0201564b46b5d04.jpg -> Healthy_523.jpg
# healty_538_jpg.rf.c46c154e3ba53cb1e97a204bcb1a1655.jpg -> Healthy_524.jpg
# healty_53_jpg.rf.2b8cfd4a4c0af26d03662ff3c698d6e7.jpg -> Healthy_525.jpg
# healty_559_jpg.rf.14b73a776422b872662d2c560c31b09e.jpg -> Healthy_526.jpg
# healty_555_jpg.rf.a2096e7c76c8e642e10b684858e448a7.jpg -> Healthy_527.jpg
# healty_556_jpg.rf.f39dab806488e230faee22d042e8b4ef.jpg -> Healthy_528.jpg
# healty_550_jpg.rf.ea6cc4b956c41daeb1492f32cc770600.jpg -> Healthy_529.jpg
# healty_553_jpg.rf.e9b0185f86dcad34b595c547d2ea927d.jpg -> Healthy_530.jpg
# healty_568_jpg.rf.e9b3e4b78ed4b3275dc88c537f6d7532.jpg -> Healthy_531.jpg
# healty_571_jpg.rf.da1e0512a3346d9629b42c9ea29c471e.jpg -> Healthy_532.jpg
# healty_57_jpg.rf.7e56f16d4cfe7ce416cf4a2cebea7bb3.jpg -> Healthy_533.jpg
# healty_569_jpg.rf.83536e5dd367f7164859d20f40764fc8.jpg -> Healthy_534.jpg
# healty_591_jpg.rf.7a48e9f983296ad90d4e53da00f72d11.jpg -> Healthy_535.jpg
# healty_585_jpg.rf.285028d8f9c0ecf8feae5068d3ba34a3.jpg -> Healthy_536.jpg
# healty_590_jpg.rf.edae4bcbf998ae97584d3c928a0fe999.jpg -> Healthy_537.jpg
# healty_597_jpg.rf.3f785a33e4bc7d121964d1bc6a51d069.jpg -> Healthy_538.jpg
# healty_596_jpg.rf.46e8ea48088d9116aeb053b9cd40fca5.jpg -> Healthy_539.jpg
# healty_5_jpg.rf.8fa10391bb24ed36a91bb38277cb4a0a.jpg -> Healthy_540.jpg
# healty_598_jpg.rf.1a62634e5cb43eb900f0ec9d407cf2ea.jpg -> Healthy_541.jpg
# healty_599_jpg.rf.a17948afcfbd115fe2c01dc683397466.jpg -> Healthy_542.jpg
# healty_601_jpg.rf.b562b5559f25d9e7c47bb28631e0e00f.jpg -> Healthy_543.jpg
# healty_606_jpg.rf.901dccb6c4b1e8de668bdd8dde2a5ad6.jpg -> Healthy_544.jpg
# healty_600_jpg.rf.1e37788f7edff609a0301043fc619ecc.jpg -> Healthy_545.jpg
# healty_609_jpg.rf.d1cde5fbaff73e5ce014fd2e7aa0003f.jpg -> Healthy_546.jpg
# healty_622_jpg.rf.f445b859aeec1b667e2d5de6b794f562.jpg -> Healthy_547.jpg
# healty_626_jpg.rf.1c3959e68da4075c33057973d1d173ae.jpg -> Healthy_548.jpg
# healty_638_jpg.rf.612bcddf3a6354285d184bb688343141.jpg -> Healthy_549.jpg
# healty_643_jpg.rf.67a16e59be29e5b17a5cc3e09ad9c4b4.jpg -> Healthy_550.jpg
# healty_642_jpg.rf.3c0e023930ed3b79cdc56092d21fc4b4.jpg -> Healthy_551.jpg
# healty_650_jpg.rf.3ec416ea6fa3f3c66e547f3db57fff84.jpg -> Healthy_552.jpg
# healty_656_jpg.rf.91770c07fb53d27bb08f4cbdbbf107c3.jpg -> Healthy_553.jpg
# healty_659_jpg.rf.e3714ea5c8e289816f59a95eebedb1c0.jpg -> Healthy_554.jpg
# healty_667_jpg.rf.946c1657455bdeea6498f7a5bd38a176.jpg -> Healthy_555.jpg
# healty_662_jpg.rf.d782f470ea05654c1d82af7bcf0e555d.jpg -> Healthy_556.jpg
# healty_663_jpg.rf.62d5014bbebad088a589500cda1a2dcb.jpg -> Healthy_557.jpg
# healty_671_jpg.rf.e38dfa624c20faa259fee5b636ca9799.jpg -> Healthy_558.jpg
# healty_668_jpg.rf.0aaca6fd09d693a16d079d868240bf54.jpg -> Healthy_559.jpg
# healty_670_jpg.rf.36d762917c51d3ecac64162342a48f0d.jpg -> Healthy_560.jpg
# healty_661_jpg.rf.d0744790e50ec9696d87d675255b2c19.jpg -> Healthy_561.jpg
# healty_666_jpg.rf.00589de73390a3dd87ecc08e09ffb7af.jpg -> Healthy_562.jpg
# healty_660_jpg.rf.febde50646ce87649b987463b0715fdc.jpg -> Healthy_563.jpg
# healty_676_jpg.rf.69e5b6f7df9c3cf548b6f51da6093a46.jpg -> Healthy_564.jpg
# healty_675_jpg.rf.a5842eb7283f43c80c6cbfedf91159be.jpg -> Healthy_565.jpg
# healty_693_jpg.rf.aad9bf6d95ff81d0d5b8330da21d831d.jpg -> Healthy_566.jpg
# healty_714_jpg.rf.c8d4121b5bdf92e210c50f97a1a566a0.jpg -> Healthy_567.jpg
# healty_715_jpg.rf.debb059165e3493727f5a3445f6f8d2e.jpg -> Healthy_568.jpg
# healty_717_jpg.rf.19cf4b3d7073b2a76ac10f6c94305322.jpg -> Healthy_569.jpg
# healty_730_jpg.rf.48768122110a71cc6aab44a9e17e1b6b.jpg -> Healthy_570.jpg
# healty_731_jpg.rf.540ebba64b7766563e6c8737ca3f49cf.jpg -> Healthy_571.jpg
# healty_740_jpg.rf.f68a7604119653b12b0849c83f400eb1.jpg -> Healthy_572.jpg
# healty_732_jpg.rf.2a40b18221f4cb57a0be259d86ed0e33.jpg -> Healthy_573.jpg
# healty_743_jpg.rf.8d717a6bb659375e4fde21337f1290c4.jpg -> Healthy_574.jpg
# healty_747_jpg.rf.bfb4e2b6a9feef614bf2ef9453b36ba0.jpg -> Healthy_575.jpg
# healty_741_jpg.rf.1a9ae70843f839a896566785cf67a7cd.jpg -> Healthy_576.jpg
# healty_751_jpg.rf.8cbab6365bf6272835fdeda40e7c5df9.jpg -> Healthy_577.jpg
# healty_742_jpg.rf.0b9c7a558b9a2c000e2eaf5372c0d0d6.jpg -> Healthy_578.jpg
# healty_75_jpg.rf.ec767c476a3b8175f4033c95bd60e8ea.jpg -> Healthy_579.jpg
# healty_793_jpg.rf.2f31dc0cb4f9b717534edbe1a4b25662.jpg -> Healthy_580.jpg
# healty_791_jpg.rf.91a00f6ba706dbc2779faee2980f410d.jpg -> Healthy_581.jpg
# healty_792_jpg.rf.85a22a8a583e5ee5692a6d8cb27bb050.jpg -> Healthy_582.jpg
# healty_801_jpg.rf.877354075081cf564d4fb84731b30de5.jpg -> Healthy_583.jpg
# healty_815_jpg.rf.92309272ef24d581a2ca88ede83c4e88.jpg -> Healthy_584.jpg
# healty_84_jpg.rf.e5d386a6e37dfbe4fd4f7ada0778ae70.jpg -> Healthy_585.jpg
# healty_85_jpg.rf.e681655dfc84069ce2e4d871a34d84a3.jpg -> Healthy_586.jpg
# healty_876_jpg.rf.22c5411dc2ae3c31f2ad2b20b3f7a0d1.jpg -> Healthy_587.jpg
# healty_86_jpg.rf.7980fb40d9c0d919c18669055beac55e.jpg -> Healthy_588.jpg
# healty_883_jpg.rf.8ee43d2268149b1b55c76deeee8af8e9.jpg -> Healthy_589.jpg
# healty_884_jpg.rf.2d5b4a50092e8d73e3432d2d3f337f79.jpg -> Healthy_590.jpg
# healty_87_jpg.rf.d42e3ea93388340f8297c66a3b92b68b.jpg -> Healthy_591.jpg
# healty_898_jpg.rf.e5a36ab7815f03f7e55bf5aee5bdb599.jpg -> Healthy_592.jpg
# healty_893_jpg.rf.5e7d31b0f3040692cc1fc4e7e03fc7e5.jpg -> Healthy_593.jpg
# healty_905_jpg.rf.bd244d781635a48401884bbe71631c3d.jpg -> Healthy_594.jpg
# healty_897_jpg.rf.ad4ede2b79e83d0aaaa80a593e722346.jpg -> Healthy_595.jpg
# healty_900_jpg.rf.44ff7f0c7de53cae93b55dc798f24263.jpg -> Healthy_596.jpg
# healty_912_jpg.rf.e1428bd0896f00c83aaeb24d6db763fc.jpg -> Healthy_597.jpg
# healty_90_jpg.rf.f859f15129fa002cc9df065c64f44ea9.jpg -> Healthy_598.jpg
# healty_914_jpg.rf.b831faec6f2000cc3b59f122b53c1988.jpg -> Healthy_599.jpg
# healty_92_jpg.rf.6b2521a071f4db46f51baa0792431e61.jpg -> Healthy_600.jpg
# healty_933_jpg.rf.c7e21ead36c4c07996d2d17ad1b275f6.jpg -> Healthy_601.jpg
# healty_928_jpg.rf.10b36963e9fb251117b9a9dcb7a59641.jpg -> Healthy_602.jpg
# healty_929_jpg.rf.1eaab052a042373d2ec3dfa4cb00e91e.jpg -> Healthy_603.jpg
# healty_953_jpg.rf.7c020d66f0cd482b1c0fc7d474346fc3.jpg -> Healthy_604.jpg
# healty_951_jpg.rf.2af7996172cf8a288d3c432f8c3456ad.jpg -> Healthy_605.jpg
# healty_952_jpg.rf.e6c7288fea3a74db741432492e71bf74.jpg -> Healthy_606.jpg
# healty_960_jpg.rf.85abb00e767f6ea0d279acc91840bc61.jpg -> Healthy_607.jpg
# healty_958_jpg.rf.8ab705b1d547c62eab932230f542c887.jpg -> Healthy_608.jpg
# healty_962_jpg.rf.0e6b638bf8870b78dbd36bc9da6e2e18.jpg -> Healthy_609.jpg
# healty_963_jpg.rf.8442557ca69a6e351893318699c99a89.jpg -> Healthy_610.jpg
# healty_959_jpg.rf.1f1907fa832ff73ba1a0e40d526384c6.jpg -> Healthy_611.jpg
# healty_972_jpg.rf.6112b47c6b455a4bec62420d928560a1.jpg -> Healthy_612.jpg
# healty_97_jpg.rf.f14013efb0e170ab3d1fa157e8030172.jpg -> Healthy_613.jpg
# healty_978_jpg.rf.7367058418c2b492d6a5eface4988341.jpg -> Healthy_614.jpg
# healty_991_jpg.rf.040a580bb4b96ebcbc0b44d90670704a.jpg -> Healthy_615.jpg
# healty_98_jpg.rf.d60d0f77014719cd27ebd9e9dd6372b1.jpg -> Healthy_616.jpg
# healty_986_jpg.rf.1333281c0dc2c4b4202e8e0d172cd3e7.jpg -> Healthy_617.jpg
# healty_982_jpg.rf.5dc72cd50ba6f3093b267d25affdae6b.jpg -> Healthy_618.jpg
# healty_997_jpg.rf.b5cdcbdecbb50f3a4cfcd4bd72568713.jpg -> Healthy_619.jpg
#
# Jumlah gambar di kategori 'Healthy': 619
#
# =================
# Total gambar di dataset: 1372

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

# Menghitung jumlah gambar di setiap kategori
category_counts = {}
for category in categories:
    category_dir = os.path.join(DATASET_DIR, category)
    if os.path.isdir(category_dir):
        count = len([file for file in os.listdir(category_dir) if os.path.isfile(os.path.join(category_dir, file))])
        category_counts[category] = count

# 1. Visualisasi Distribusi Jumlah Gambar per Kategori
plt.figure(figsize=(8, 5))
plt.bar(category_counts.keys(), category_counts.values(), color=['skyblue', 'orange'])
plt.title('Distribusi Jumlah Gambar per Kategori', fontsize=14)
plt.xlabel('Kategori', fontsize=12)
plt.ylabel('Jumlah Gambar', fontsize=12)
plt.show()

# 2. Menampilkan Contoh Gambar dari Setiap Kategori
fig, axs = plt.subplots(1, len(categories), figsize=(15, 5))

for i, category in enumerate(categories):
    category_dir = os.path.join(DATASET_DIR, category)
    example_images = random.sample(os.listdir(category_dir), 3)  # Pilih 3 gambar acak
    axs[i].set_title(category)
    axs[i].imshow(mpimg.imread(os.path.join(category_dir, example_images[0])))
    axs[i].axis('off')

plt.suptitle('Contoh Gambar dari Setiap Kategori', fontsize=16)
plt.show()

# %%
# import os
# import random
# from shutil import copy

# # Fungsi untuk split data
# def split_data(new_dir, output_dir, train_ratio=0.8, valid_ratio=0.1):
#     if not os.path.exists(output_dir):
#         os.makedirs(output_dir)

#     train_dir = os.path.join(output_dir, 'train')
#     valid_dir = os.path.join(output_dir, 'validation')
#     test_dir = os.path.join(output_dir, 'test')

#     if not os.path.exists(train_dir): os.makedirs(train_dir)
#     if not os.path.exists(valid_dir): os.makedirs(valid_dir)
#     if not os.path.exists(test_dir): os.makedirs(test_dir)

#     categories = ['Down Syndrome', 'Healthy']
#     for category in categories:
#         category_path = os.path.join(new_dir, category)
#         images = [
#             os.path.join(category_path, img)
#             for img in os.listdir(category_path)
#             if img.lower().endswith(('.jpg', '.png', '.jpeg'))
#         ]

#         print(f"Jumlah gambar '{category}' sebelum pembagian: {len(images)}")
#         random.shuffle(images)

#         train_split = int(train_ratio * len(images))
#         valid_split = int((train_ratio + valid_ratio) * len(images))

#         for i, img_path in enumerate(images):
#             if i < train_split:
#                 target_dir = os.path.join(train_dir, category)
#             elif i < valid_split:
#                 target_dir = os.path.join(valid_dir, category)
#             else:
#                 target_dir = os.path.join(test_dir, category)

#             if not os.path.exists(target_dir):
#                 os.makedirs(target_dir)

#             copy(img_path, target_dir)

#         print(f"Jumlah gambar '{category}' setelah pembagian:")
#         print(f"  Train: {len(os.listdir(os.path.join(train_dir, category)))}")
#         print(f"  Validation: {len(os.listdir(os.path.join(valid_dir, category)))}")
#         print(f"  Test: {len(os.listdir(os.path.join(test_dir, category)))}")

#     print("\nSplitting selesai.")
#     return train_dir, valid_dir, test_dir

# # Fungsi untuk mengecek jumlah file dalam subfolder
# def count_files_in_subfolders(directory):
#     counts = {}
#     for folder in os.listdir(directory):
#         folder_path = os.path.join(directory, folder)
#         if os.path.isdir(folder_path):
#             counts[folder] = len([f for f in os.scandir(folder_path) if f.is_file()])
#     return counts

# # Path input dan output dataset
# OUTPUT_DIR = '/content/drive/MyDrive/DATASET/ASIA_RENAMED/splitted_data'

# # Proses splitting
# train_dir, valid_dir, test_dir = split_data(NEW_DIR, OUTPUT_DIR)
# Out:
# Jumlah gambar 'Down Syndrome' sebelum pembagian: 753
# Jumlah gambar 'Down Syndrome' setelah pembagian:
#   Train: 602
#   Validation: 75
#   Test: 76
# Jumlah gambar 'Healthy' sebelum pembagian: 619
# Jumlah gambar 'Healthy' setelah pembagian:
#   Train: 495
#   Validation: 62
#   Test: 62
#
# Splitting selesai.

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# import os
# import random

# # Fungsi untuk menghitung jumlah gambar di setiap folder
# def count_images_by_category(folder_dir, categories):
#     counts = {}
#     for category in categories:
#         category_path = os.path.join(folder_dir, category)
#         if os.path.exists(category_path):
#             counts[category] = len([img for img in os.listdir(category_path) if img.lower().endswith(('.jpg', '.png', '.jpeg'))])
#         else:
#             counts[category] = 0
#     return counts

# # Visualisasi Distribusi Dataset
# def visualize_distribution(train_dir, valid_dir, test_dir, categories):
#     train_counts = count_images_by_category(train_dir, categories)
#     valid_counts = count_images_by_category(valid_dir, categories)
#     test_counts = count_images_by_category(test_dir, categories)

#     data = {
#         "Train": list(train_counts.values()),
#         "Validation": list(valid_counts.values()),
#         "Test": list(test_counts.values()),
#     }

#     # Bar plot
#     x = categories
#     bar_width = 0.25
#     positions = [i for i, _ in enumerate(x)]

#     plt.figure(figsize=(10, 6))
#     plt.bar(positions, data["Train"], color='skyblue', width=bar_width, label='Train')
#     plt.bar([p + bar_width for p in positions], data["Validation"], color='orange', width=bar_width, label='Validation')
#     plt.bar([p + bar_width * 2 for p in positions], data["Test"], color='green', width=bar_width, label='Test')

#     plt.xlabel("Categories", fontsize=12)
#     plt.ylabel("Number of Images", fontsize=12)
#     plt.title("Distribution of Images Across Train, Validation, and Test Sets", fontsize=14)
#     plt.xticks([p + bar_width for p in positions], x)
#     plt.legend()
#     plt.show()

# # Visualisasi Contoh Gambar
# def visualize_samples(base_dir, categories, num_samples=2):
#     fig, axs = plt.subplots(len(categories), num_samples, figsize=(15, 5))
#     fig.suptitle("Example Images from Each Folder", fontsize=16)

#     for i, category in enumerate(categories):
#         category_path = os.path.join(base_dir, category)
#         if os.path.exists(category_path):
#             samples = random.sample(os.listdir(category_path), min(num_samples, len(os.listdir(category_path))))
#             for j, sample in enumerate(samples):
#                 img_path = os.path.join(category_path, sample)
#                 axs[i, j].imshow(mpimg.imread(img_path))
#                 axs[i, j].set_title(f"{category}")
#                 axs[i, j].axis('off')

#     plt.tight_layout(rect=[0, 0, 1, 0.95])
#     plt.show()

# # Path setelah splitting
# train_dir = '/content/drive/MyDrive/DATASET/ASIA_RENAMED/splitted_data/train'
# valid_dir = '/content/drive/MyDrive/DATASET/ASIA_RENAMED/splitted_data/validation'
# test_dir = '/content/drive/MyDrive/DATASET/ASIA_RENAMED/splitted_data/test'

# # Kategori
# categories = ['Down Syndrome', 'Healthy']

# # Visualisasi Distribusi
# visualize_distribution(train_dir, valid_dir, test_dir, categories)

# # Visualisasi Contoh Gambar dari Train
# print("Contoh gambar dari folder Train:")
# visualize_samples(train_dir, categories, num_samples=3)

# # Visualisasi Contoh Gambar dari Validation
# print("Contoh gambar dari folder Validation:")
# visualize_samples(valid_dir, categories, num_samples=3)

# # Visualisasi Contoh Gambar dari Test
# print("Contoh gambar dari folder Test:")
# visualize_samples(test_dir, categories, num_samples=3)
# Out:
# Contoh gambar dari folder Train:
# Contoh gambar dari folder Validation:
# Contoh gambar dari folder Test:

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# import os
# from PIL import Image
# import numpy as np

# # Direktori dataset asli dan direktori penyimpanan augmentasi
# original_dataset_dir = '/content/drive/MyDrive/DATASET/ASIA_RENAMED/splitted_data/train'
# augmented_dataset_dir = '/content/drive/MyDrive/DATASET/ASIA_RENAMED/augmented_data'

# # Buat direktori untuk menyimpan gambar augmentasi jika belum ada
# os.makedirs(augmented_dataset_dir, exist_ok=True)

# # Konfigurasi augmentasi
# datagen = ImageDataGenerator(
#     rotation_range=20,       # Rotasi gambar secara acak hingga 20 derajat
#     width_shift_range=0.1,   # Geser gambar secara horizontal hingga 20%
#     height_shift_range=0.1,  # Geser gambar secara vertikal hingga 20%
#     shear_range=0.10,        # Shear transformation
#     zoom_range=0.10,         # Zoom gambar secara acak hingga 10%
#     horizontal_flip=True,    # Membalik gambar secara horizontal
#     fill_mode='nearest'      # Metode pengisian ulang piksel kosong
# )

# def save_augmented_images(image_path, save_dir, num_augmented_images=3):
#     # Muat gambar asli
#     img = Image.open(image_path)

#     # Jika gambar memiliki mode yang bukan RGB, konversi ke RGB
#     if img.mode != 'RGB':
#         img = img.convert('RGB')

#     # Konversi gambar ke array
#     img_array = np.array(img)
#     if img_array.ndim == 3:
#         img_array = np.expand_dims(img_array, axis=0)

#     # Generator gambar augmentasi
#     aug_iter = datagen.flow(img_array, batch_size=1)

#     # Buat beberapa gambar augmentasi dan simpan
#     for i in range(num_augmented_images):
#         aug_img = next(aug_iter)[0].astype(np.uint8)  # Ambil gambar augmentasi
#         aug_img = Image.fromarray(aug_img)  # Konversi ke format gambar

#         # Menyimpan gambar augmentasi
#         base_name = os.path.basename(image_path).split('.')[0]
#         aug_img.save(os.path.join(save_dir, f"{base_name}_aug_{i+1}.jpg"))

# # Proses setiap gambar dalam dataset asli
# for category in os.listdir(original_dataset_dir):
#     category_path = os.path.join(original_dataset_dir, category)

#     # Pastikan hanya direktori yang diproses
#     if os.path.isdir(category_path):
#         save_category_path = os.path.join(augmented_dataset_dir, category)
#         os.makedirs(save_category_path, exist_ok=True)

#         for image_file in os.listdir(category_path):
#             image_path = os.path.join(category_path, image_file)

#             # Memastikan hanya memproses file gambar
#             if os.path.isfile(image_path) and image_file.lower().endswith(('.png', '.jpg', '.jpeg')):
#                 save_augmented_images(image_path, save_category_path, num_augmented_images=5)

# %%
import os
import shutil
import random

# Path asal dan tujuan
data_dir = "/content/drive/MyDrive/DATASET/ASIA"
test_dir = os.path.join(data_dir, "test_data")

# Bikin folder test_data jika belum ada
os.makedirs(test_dir, exist_ok=True)

# Loop tiap kategori (Down Syndrome & Healthy)
for category in ["Down Syndrome", "Healthy"]:
    category_path = os.path.join(data_dir, category)
    test_category_path = os.path.join(test_dir, category)

    # Bikin folder test_data untuk kategori ini
    os.makedirs(test_category_path, exist_ok=True)

    # Ambil semua gambar
    images = [img for img in os.listdir(category_path) if img.endswith(('.jpg', '.png'))]
    test_size = int(len(images) * 0.1)  # 10% buat test

    # Pilih gambar secara random untuk test
    test_images = random.sample(images, test_size)

    # Pindahin gambar ke test_data
    for img in test_images:
        shutil.move(os.path.join(category_path, img), os.path.join(test_category_path, img))

print("✅ Test data berhasil dipindahkan!")
# Out:
# ✅ Test data berhasil dipindahkan!

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold
import pandas as pd
import numpy as np
import os

# Path ke dataset utama
data_dir = '/content/drive/MyDrive/DATASET/ASIA'
test_dir = '/content/drive/MyDrive/DATASET/test_data'  # Test set tetap dipisah

# Ambil daftar gambar dan labelnya
image_paths = []
labels = []
categories = ['Down Syndrome', 'Healthy']

for label, category in enumerate(categories):
    category_path = os.path.join(data_dir, category)
    images = [os.path.join(category_path, img) for img in os.listdir(category_path) if img.endswith(('.jpg', '.png'))]
    image_paths.extend(images)
    labels.extend([label] * len(images))

# Buat DataFrame
df = pd.DataFrame({'filename': image_paths, 'label': labels})

# Ubah label ke string agar cocok dengan class_mode='categorical'
df['label'] = df['label'].astype(str)

# Set up k-fold cross-validation (5 fold)
kfolds = KFold(n_splits=5, shuffle=True, random_state=42)

# ImageDataGenerator tanpa augmentasi
train_datagen = ImageDataGenerator(rescale=1.0/255.0)
val_datagen = ImageDataGenerator(rescale=1.0/255.0)

# Test generator (konstan)
test_generator = val_datagen.flow_from_directory(
    directory=test_dir,
    target_size=(224, 224),
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)

# Menyimpan hasil setiap fold
fold_accuracies = []
fold_losses = []
fold_histories = []

# Start k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(kfolds.split(df)):
    print(f"\nTraining on fold {fold + 1}...")

    # Buat subset train & val dari DataFrame df
    train_df = df.iloc[train_idx].reset_index(drop=True)
    val_df = df.iloc[val_idx].reset_index(drop=True)

    # Training generator (tanpa augmentasi)
    train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        x_col='filename',
        y_col='label',
        target_size=(224, 224),
        class_mode='categorical',
        batch_size=32,
        shuffle=True
    )

    # Validation generator (tanpa augmentasi)
    val_generator = val_datagen.flow_from_dataframe(
        dataframe=val_df,
        x_col='filename',
        y_col='label',
        target_size=(224, 224),
        class_mode='categorical',
        batch_size=32,
        shuffle=False
    )

    # Model VGG16
    model = Sequential()
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    for layer in base_model.layers[:-5]:
        layer.trainable = False
    model.add(base_model)

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_accuracy', patience=3, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint(f'best_vgg16_fold_{fold + 1}.keras', monitor='val_accuracy', save_best_only=True)

    history = model.fit(train_generator, validation_data=val_generator, epochs=15, callbacks=[early_stopping, model_checkpoint])

    fold_accuracies.append(max(history.history['val_accuracy']))
    fold_losses.append(min(history.history['val_loss']))
    fold_histories.append(history)

    test_loss, test_acc = model.evaluate(test_generator)
    print(f"Test accuracy for fold {fold + 1}: {test_acc}")

# Output fold accuracies dan mean accuracy
print("\n=== Hasil K-Fold Cross-Validation ===")
for i, (acc, loss) in enumerate(zip(fold_accuracies, fold_losses)):
    print(f"Fold {i+1}: Accuracy = {acc:.4f}, Loss = {loss:.4f}")

# Rata-rata akurasi & loss
print(f"\nMean Accuracy: {np.mean(fold_accuracies):.4f}")
print(f"Mean Loss: {np.mean(fold_losses):.4f}")
# Out:
# Found 136 images belonging to 2 classes.
#
# Training on fold 1...
# Found 988 validated image filenames belonging to 2 classes.
# Found 248 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 443s 14s/step - accuracy: 0.5425 - loss: 0.8777 - val_accuracy: 0.7661 - val_loss: 0.6188
# Epoch 2/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 307ms/step - accuracy: 0.6469 - loss: 0.6060 - val_accuracy: 0.7298 - val_loss: 0.5206
# Epoch 3/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 293ms/step - accuracy: 0.7231 - loss: 0.5396 - val_accuracy: 0.7984 - val_loss: 0.4287
# Epoch 4/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 292ms/step - accuracy: 0.8054 - loss: 0.4431 - val_accuracy: 0.8266 - val_loss: 0.4013
# Epoch 5/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step - accuracy: 0.8915 - loss: 0.2822 - val_accuracy: 0.8629 - val_loss: 0.3635
# Epoch 6/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 275ms/step - accuracy: 0.9153 - loss: 0.2249 - val_accuracy: 0.8669 - val_loss: 0.3779
# Epoch 7/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - accuracy: 0.9478 - loss: 0.1497 - val_accuracy: 0.8629 - val_loss: 0.4217
# Epoch 8/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.9612 - loss: 0.1074 - val_accuracy: 0.8710 - val_loss: 0.4172
# Epoch 9/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 283ms/step - accuracy: 0.9745 - loss: 0.0677 - val_accuracy: 0.8790 - val_loss: 0.4912
# Epoch 10/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - accuracy: 0.9728 - loss: 0.0807 - val_accuracy: 0.8589 - val_loss: 0.5510
# Epoch 11/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 287ms/step - accuracy: 0.9970 - loss: 0.0254 - val_accuracy: 0.8871 - val_loss: 0.5611
# Epoch 12/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 271ms/step - accuracy: 0.9928 - loss: 0.0332 - val_accuracy: 0.8508 - val_loss: 0.7096
# Epoch 13/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - accuracy: 0.9958 - loss: 0.0167 - val_accuracy: 0.8831 - val_loss: 0.8271
# Epoch 14/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.9819 - loss: 0.0532 - val_accuracy: 0.8266 - val_loss: 0.5234
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 9s/step - accuracy: 0.8812 - loss: 0.4955
# Test accuracy for fold 1: 0.8676470518112183
#
# Training on fold 2...
# Found 989 validated image filenames belonging to 2 classes.
# Found 247 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.5377 - loss: 0.7597 - val_accuracy: 0.8219 - val_loss: 0.5140
# Epoch 2/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 322ms/step - accuracy: 0.7426 - loss: 0.5228 - val_accuracy: 0.8623 - val_loss: 0.3621
# Epoch 3/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 275ms/step - accuracy: 0.7943 - loss: 0.4417 - val_accuracy: 0.9028 - val_loss: 0.2773
# Epoch 4/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step - accuracy: 0.8429 - loss: 0.3720 - val_accuracy: 0.8259 - val_loss: 0.4039
# Epoch 5/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 275ms/step - accuracy: 0.8892 - loss: 0.2870 - val_accuracy: 0.9109 - val_loss: 0.2232
# Epoch 6/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 315ms/step - accuracy: 0.9355 - loss: 0.1928 - val_accuracy: 0.9231 - val_loss: 0.1980
# Epoch 7/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.9479 - loss: 0.1426 - val_accuracy: 0.9190 - val_loss: 0.2617
# Epoch 8/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.9598 - loss: 0.1215 - val_accuracy: 0.9231 - val_loss: 0.2258
# Epoch 9/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 295ms/step - accuracy: 0.9771 - loss: 0.0680 - val_accuracy: 0.9474 - val_loss: 0.1675
# Epoch 10/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - accuracy: 0.9752 - loss: 0.0927 - val_accuracy: 0.9555 - val_loss: 0.1647
# Epoch 11/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 261ms/step - accuracy: 0.9873 - loss: 0.0413 - val_accuracy: 0.9231 - val_loss: 0.2415
# Epoch 12/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - accuracy: 0.9943 - loss: 0.0285 - val_accuracy: 0.8988 - val_loss: 0.3490
# Epoch 13/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 290ms/step - accuracy: 0.9911 - loss: 0.0342 - val_accuracy: 0.9271 - val_loss: 0.4020
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.9082 - loss: 0.4602
# Test accuracy for fold 2: 0.904411792755127
#
# Training on fold 3...
# Found 989 validated image filenames belonging to 2 classes.
# Found 247 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 413ms/step - accuracy: 0.5364 - loss: 0.8009 - val_accuracy: 0.7733 - val_loss: 0.6389
# Epoch 2/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 291ms/step - accuracy: 0.6366 - loss: 0.6342 - val_accuracy: 0.8097 - val_loss: 0.5043
# Epoch 3/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 322ms/step - accuracy: 0.7287 - loss: 0.5139 - val_accuracy: 0.8543 - val_loss: 0.3410
# Epoch 4/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.8099 - loss: 0.4029 - val_accuracy: 0.8947 - val_loss: 0.2724
# Epoch 5/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 265ms/step - accuracy: 0.8799 - loss: 0.2883 - val_accuracy: 0.8785 - val_loss: 0.2773
# Epoch 6/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 294ms/step - accuracy: 0.9050 - loss: 0.2207 - val_accuracy: 0.9190 - val_loss: 0.2254
# Epoch 7/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 263ms/step - accuracy: 0.9505 - loss: 0.1497 - val_accuracy: 0.9069 - val_loss: 0.2437
# Epoch 8/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 283ms/step - accuracy: 0.9704 - loss: 0.0854 - val_accuracy: 0.9312 - val_loss: 0.2201
# Epoch 9/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - accuracy: 0.9860 - loss: 0.0609 - val_accuracy: 0.9231 - val_loss: 0.2469
# Epoch 10/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step - accuracy: 0.9800 - loss: 0.0407 - val_accuracy: 0.9150 - val_loss: 0.2792
# Epoch 11/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9893 - loss: 0.0384 - val_accuracy: 0.9028 - val_loss: 0.2916
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.8808 - loss: 0.4670
# Test accuracy for fold 3: 0.8897058963775635
#
# Training on fold 4...
# Found 989 validated image filenames belonging to 2 classes.
# Found 247 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 16s 381ms/step - accuracy: 0.5387 - loss: 0.8596 - val_accuracy: 0.7328 - val_loss: 0.5911
# Epoch 2/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.6588 - loss: 0.5981 - val_accuracy: 0.7611 - val_loss: 0.4671
# Epoch 3/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 268ms/step - accuracy: 0.7857 - loss: 0.4689 - val_accuracy: 0.7247 - val_loss: 0.5062
# Epoch 4/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step - accuracy: 0.8097 - loss: 0.4016 - val_accuracy: 0.8421 - val_loss: 0.3821
# Epoch 5/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 266ms/step - accuracy: 0.9010 - loss: 0.2867 - val_accuracy: 0.8300 - val_loss: 0.3651
# Epoch 6/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 316ms/step - accuracy: 0.9222 - loss: 0.1959 - val_accuracy: 0.8543 - val_loss: 0.4153
# Epoch 7/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 318ms/step - accuracy: 0.9200 - loss: 0.1580 - val_accuracy: 0.8664 - val_loss: 0.3891
# Epoch 8/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 311ms/step - accuracy: 0.9618 - loss: 0.0942 - val_accuracy: 0.9028 - val_loss: 0.2681
# Epoch 9/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - accuracy: 0.9680 - loss: 0.0963 - val_accuracy: 0.8907 - val_loss: 0.3998
# Epoch 10/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.9804 - loss: 0.0545 - val_accuracy: 0.8623 - val_loss: 0.7386
# Epoch 11/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step - accuracy: 0.9795 - loss: 0.0610 - val_accuracy: 0.8866 - val_loss: 0.4284
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.8469 - loss: 0.4349
# Test accuracy for fold 4: 0.8676470518112183
#
# Training on fold 5...
# Found 989 validated image filenames belonging to 2 classes.
# Found 247 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 399ms/step - accuracy: 0.5419 - loss: 0.8114 - val_accuracy: 0.5992 - val_loss: 0.6493
# Epoch 2/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 283ms/step - accuracy: 0.6419 - loss: 0.6180 - val_accuracy: 0.7328 - val_loss: 0.5294
# Epoch 3/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.7258 - loss: 0.5461 - val_accuracy: 0.6761 - val_loss: 0.5842
# Epoch 4/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 286ms/step - accuracy: 0.7437 - loss: 0.5176 - val_accuracy: 0.7814 - val_loss: 0.4290
# Epoch 5/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8623 - loss: 0.3291 - val_accuracy: 0.8259 - val_loss: 0.3496
# Epoch 6/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8968 - loss: 0.2433 - val_accuracy: 0.8826 - val_loss: 0.2819
# Epoch 7/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.9364 - loss: 0.1608 - val_accuracy: 0.8421 - val_loss: 0.3071
# Epoch 8/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 263ms/step - accuracy: 0.9408 - loss: 0.1631 - val_accuracy: 0.8704 - val_loss: 0.4337
# Epoch 9/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 286ms/step - accuracy: 0.9297 - loss: 0.1662 - val_accuracy: 0.8988 - val_loss: 0.2917
# Epoch 10/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 285ms/step - accuracy: 0.9710 - loss: 0.0940 - val_accuracy: 0.9028 - val_loss: 0.3661
# Epoch 11/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 266ms/step - accuracy: 0.9918 - loss: 0.0511 - val_accuracy: 0.8745 - val_loss: 0.4736
# Epoch 12/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.9854 - loss: 0.0412 - val_accuracy: 0.8543 - val_loss: 0.6770
# Epoch 13/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9924 - loss: 0.0247 - val_accuracy: 0.8543 - val_loss: 0.7490
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.8481 - loss: 0.8198
# Test accuracy for fold 5: 0.875
#
# === Hasil K-Fold Cross-Validation ===
# Fold 1: Accuracy = 0.8871, Loss = 0.3635
# Fold 2: Accuracy = 0.9555, Loss = 0.1647
# Fold 3: Accuracy = 0.9312, Loss = 0.2201
# Fold 4: Accuracy = 0.9028, Loss = 0.2681
# Fold 5: Accuracy = 0.9028, Loss = 0.2819
#
# Mean Accuracy: 0.9159
# Mean Loss: 0.2597

# %%
# Pilih fold terbaik berdasarkan validasi akurasi maksimum
best_fold_index = np.argmax(fold_accuracies)  # Index fold terbaik
print(f"Fold terbaik adalah Fold {best_fold_index + 1} dengan akurasi {fold_accuracies[best_fold_index]:.4f}")

# Ambil history fold terbaik
best_history = fold_histories[best_fold_index]

# Grafik Akurasi untuk fold terbaik
plt.figure(figsize=(12, 6))

# Plot Akurasi
plt.subplot(1, 2, 1)
plt.plot(best_history.history['accuracy'], label='Train Accuracy')
plt.plot(best_history.history['val_accuracy'], label='Validation Accuracy', linestyle='--')
plt.title(f'Akurasi Fold Terbaik (Fold {best_fold_index + 1})')
plt.xlabel('Epoch')
plt.ylabel('Akurasi')
plt.legend()

# Grafik Loss untuk fold terbaik
plt.subplot(1, 2, 2)
plt.plot(best_history.history['loss'], label='Train Loss')
plt.plot(best_history.history['val_loss'], label='Validation Loss', linestyle='--')
plt.title(f'Loss Fold Terbaik (Fold {best_fold_index + 1})')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Tampilkan akurasi dan loss untuk fold terbaik
print(f"Akurasi terbaik pada fold {best_fold_index + 1}: {fold_accuracies[best_fold_index]:.4f}")
print(f"Loss terbaik pada fold {best_fold_index + 1}: {fold_losses[best_fold_index]:.4f}")
# Out:
# Fold terbaik adalah Fold 2 dengan akurasi 0.9555
# Akurasi terbaik pada fold 2: 0.9555
# Loss terbaik pada fold 2: 0.1647

# %%
import tensorflow as tf
from sklearn.metrics import classification_report
import numpy as np

# Pilih fold terbaik berdasarkan validasi akurasi maksimum
best_fold_index = np.argmax(fold_accuracies)  # Index fold terbaik
print(f"Fold terbaik adalah Fold {best_fold_index + 1} dengan akurasi {fold_accuracies[best_fold_index]:.4f}")

# Load model terbaik dari fold terbaik
best_model_path = f'best_vgg16_fold_{best_fold_index + 1}.keras'
best_model = tf.keras.models.load_model(best_model_path)

# Test generator untuk fold terbaik (Gunakan ImageDataGenerator baru, tanpa validation_split)
test_datagen = ImageDataGenerator(rescale=1.0/255.0)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    class_mode='categorical',  # Harus 'categorical' karena model pakai softmax
    batch_size=32,
    shuffle=False  # Jangan di-shuffle supaya urutan gambar tetap
)

# Dapatkan prediksi untuk fold terbaik
predictions = best_model.predict(test_generator)

# Konversi hasil softmax menjadi label kelas
y_pred = np.argmax(predictions, axis=1)  # Pilih kelas dengan probabilitas tertinggi

# Ambil label asli (y_true) dari generator
y_true = test_generator.classes  # Label asli dari test set

# Class labels untuk laporan
class_labels = list(test_generator.class_indices.keys())

# Generate classification report untuk fold terbaik
report = classification_report(y_true, y_pred, target_names=class_labels)

# Tampilkan laporan
print("Classification Report for Best Fold:")
print(report)

# (Optional) Simpan laporan ke file
# with open(f'classification_report_fold_{best_fold_index + 1}.txt', 'w') as f:
#     f.write(report)
# Out:
# Fold terbaik adalah Fold 2 dengan akurasi 0.9555
# Found 136 images belonging to 2 classes.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 355ms/step
# Classification Report for Best Fold:
#                precision    recall  f1-score   support
#
# Down Syndrome       0.90      0.93      0.92        75
#       Healthy       0.91      0.87      0.89        61
#
#      accuracy                           0.90       136
#     macro avg       0.91      0.90      0.90       136
#  weighted avg       0.90      0.90      0.90       136

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Pilih fold terbaik berdasarkan validasi akurasi maksimum
best_fold_index = np.argmax(fold_accuracies)  # Index fold terbaik
print(f"Fold terbaik adalah Fold {best_fold_index + 1} dengan akurasi {fold_accuracies[best_fold_index]:.4f}")

# Load model terbaik dari fold terbaik
best_model_path = f'best_vgg16_fold_{best_fold_index + 1}.keras'
best_model = tf.keras.models.load_model(best_model_path)

# Test generator untuk fold terbaik (tanpa validation_split)
test_datagen = ImageDataGenerator(rescale=1.0/255.0)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    class_mode='categorical',  # Sesuai dengan softmax output
    batch_size=32,
    shuffle=False  # Jangan di-shuffle supaya urutan gambar tetap
)

# Dapatkan prediksi untuk fold terbaik
predictions = best_model.predict(test_generator)

# Konversi hasil softmax menjadi label kelas
y_pred = np.argmax(predictions, axis=1)  # Pilih kelas dengan probabilitas tertinggi

# Ambil label asli (y_true) dari generator
y_true = test_generator.classes  # Label asli dari test set

# Generate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix dengan seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title(f"Confusion Matrix for Fold {best_fold_index + 1}")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Fold terbaik adalah Fold 2 dengan akurasi 0.9555
# Found 136 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Ambil daftar label kelas dari test generator
class_labels = list(test_generator.class_indices.keys())

# Indeks kesalahan prediksi
misclassified_indices = np.where(y_pred != y_true)[0]

# Filter berdasarkan jenis kesalahan
ds_as_healthy = [idx for idx in misclassified_indices if y_true[idx] == 0 and y_pred[idx] == 1]  # DS → Healthy
healthy_as_ds = [idx for idx in misclassified_indices if y_true[idx] == 1 and y_pred[idx] == 0]  # Healthy → DS

print(f"Jumlah DS diprediksi sebagai Healthy: {len(ds_as_healthy)}")
print(f"Jumlah Healthy diprediksi sebagai DS: {len(healthy_as_ds)}")

# Fungsi untuk menampilkan gambar
def plot_misclassified_images(indices, title, rows=2, cols=5):
    plt.figure(figsize=(cols * 3, rows * 3))
    for i, idx in enumerate(indices[:rows * cols]):  # Batasi agar grid tidak terlalu besar
        img_path = test_generator.filepaths[idx]
        img = Image.open(img_path)

        plt.subplot(rows, cols, i + 1)
        plt.imshow(img)
        true_label = class_labels[y_true[idx]]
        pred_label = class_labels[y_pred[idx]]
        plt.title(f"True: {true_label}\nPred: {pred_label}", fontsize=10)
        plt.axis('off')

    plt.suptitle(title, fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()

# Tampilkan kesalahan prediksi DS → Healthy
if ds_as_healthy:
    plot_misclassified_images(ds_as_healthy, "Down Syndrome diprediksi sebagai Healthy")

# Tampilkan kesalahan prediksi Healthy → DS
if healthy_as_ds:
    plot_misclassified_images(healthy_as_ds, "Healthy diprediksi sebagai Down Syndrome")
# Out:
# Jumlah DS diprediksi sebagai Healthy: 5
# Jumlah Healthy diprediksi sebagai DS: 8

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 7, 7, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 38,532,872 (146.99 MB)
#  Trainable params: 10,299,202 (39.29 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)
#  Optimizer params: 20,598,406 (78.58 MB)
